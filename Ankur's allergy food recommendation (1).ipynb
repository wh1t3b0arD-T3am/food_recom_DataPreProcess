# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import random

# %% [markdown]
# ## User Inputs:
#
#     1. Age
# 	2. Weight
# 	3. Height
# 	4. Gender
# 	5. Activeness Level {Sedentary / Light Activity / Moderate Activity / Active / Very Active}
# 	6. Health Issues {Diabetes / Hypertension / Hypotension / None}
# 	7. Any Bad Habits {Smoking / Alcohol / Both / None}
# 	8. Your Goal {Lose Weight / Maintain Weight / Gain Weight}
# 	9. Allergic to any specified Food (If any) {Blank Space to type}
#
# <br>***Description of Activeness Levels / Activity Multiplier:***<br>
#
#     1. Sedentary = BMR x 1.2 (little or no exercise, desk job)
#     2. Lightly active = BMR x 1.375 (light exercise/ sports 1-3 days/week)
#     3. Moderately active = BMR x 1.55 (moderate exercise/ sports 6-7 days/week)
#     4. Very active = BMR x 1.725 (hard exercise every day, or exercising 2 hours/day)
#     5. Extra active = BMR x 1.9 (hard exercise 2 or more times per day, or training for marathon, or triathlon, etc.)

# %%
"""Activity Multiplier as Dictionary"""
activity_multiplier = {
    "Sedentary": 1.2,
    "Lightly Active": 1.375,
    "Moderately Active": 1.55,
    "Very Active": 1.725,
    "Extra Active": 1.9
}

"""Loading Dataset"""
recipe_df = pd.read_csv(r"C:\Users\ankur\OneDrive\Desktop\Internship\recipe_nutrient.csv", nrows=10000)
recipe_df = recipe_df.drop(['Unnamed: 0', 'Unnamed: 0.1', "partition"], axis=1)
nrows = recipe_df.shape[0]
recipe_df.head()
# Out:
#                                          ingredients  \
# 0  [{'text': '2 12 cups milk'}, {'text': '1 12 cu...
# 1  [{'text': '1 (3 ounce) package watermelon gela...
# 2  [{'text': '12 cup shredded coconut'}, {'text':...
# 3  [{'text': '6 -8 cups fresh rhubarb, or'}, {'te...
# 4  [{'text': '2 cups flour'}, {'text': '1 tablesp...
#
#                                                  url  \
# 0  http://www.food.com/recipe/crunchy-onion-potat...
# 1  http://www.food.com/recipe/cool-n-easy-creamy-...
# 2  http://www.food.com/recipe/easy-tropical-beef-...
# 3  http://www.food.com/recipe/strawberry-rhubarb-...
# 4  http://www.food.com/recipe/zucchini-nut-bread-...
#
#                                 title          id  \
# 0           Crunchy Onion Potato Bake  00003a70b1
# 1  Cool 'n Easy Creamy Watermelon Pie  00004320bb
# 2          Easy Tropical Beef Skillet  0000631d90
# 3        Strawberry Rhubarb Dump Cake  00007bfd16
# 4                  Zucchini Nut Bread  0000973574
#
#                                         instructions  \
# 0  [{'text': 'Preheat oven to 350 degrees Fahrenh...
# 1  [{'text': 'Dissolve Jello in boiling water.'},...
# 2  [{'text': 'In a large skillet, toast the cocon...
# 3  [{'text': 'Put ingredients in a buttered 9 x 1...
# 4  [{'text': 'Sift dry ingredients.'}, {'text': '...
#
#                                            nutrition  calories  fatContent  \
# 0  {'calories': '240.7', 'fatContent': '18', 'sat...     240.7        18.0
# 1  {'calories': '392.6', 'fatContent': '24.4', 's...     392.6        24.4
# 2  {'calories': '472.5', 'fatContent': '23.8', 's...     472.5        23.8
# 3  {'calories': '431.8', 'fatContent': '12.6', 's...     431.8        12.6
# 4  {'calories': '683.3', 'fatContent': '39', 'sat...     683.3        39.0
#
#    saturatedFatContent  cholesterolContent  sodiumContent  \
# 0                 11.2                54.3          363.2
# 1                 14.4                 0.0          242.7
# 2                  9.9                73.7          469.9
# 3                  5.6                20.3          428.4
# 4                  5.1                79.3          647.3
#
#    carbohydrateContent  fiberContent  sugarContent  proteinContent
# 0                 12.3           0.8           1.1             9.1
# 1                 42.9           0.8          31.5             2.7
# 2                 40.1           3.7          26.3            27.4
# 3                 78.1           2.7          62.4             4.1
# 4                 77.9           2.6          51.3             8.2

# %%
def calculate_bmr_tdee(age, weight, height, gender, activeness, goal):
    
    if gender == "Male":
        bmr = round(5 + (10 * weight) + (6.25 * height) - (5 * age), ndigits=2)
        tdee = round(bmr * activity_multiplier.get(activeness), ndigits=2)
        print("\nUser's BMR - {}kcal & TDEE - {}kcal".format(bmr, tdee))
    else:
        bmr = round((9.247 * weight) + (3.098 * height) - (4.33 * age) - 161, ndigits=2)
        tdee = round(bmr * activity_multiplier.get(activeness), ndigits=2)
        print("\nUser's BMR - {}kcal & TDEE - {}kcal".format(bmr, tdee))
    
    
    if goal == "Lose Weight":
        final_tdee = tdee - 500
        print("Final TDEE - {}kcal".format(final_tdee))
    elif goal == "Maintain Weight":
        final_tdee = tdee
        print("Final TDEE - {}kcal".format(final_tdee))
    else:
        final_tdee = tdee + 500
        print("Final TDEE - {}kcal".format(final_tdee))
    return bmr, final_tdee


def calculate_nutritional_limits_day(final_tdee):
    
    if health_issues == "Diabetes":
        min_carbs = round((final_tdee * 0.4) / 4, ndigits=2)
        max_carbs = round((final_tdee * 0.5) / 4, ndigits=2)
        min_fats = round((final_tdee * 0.25) / 9, ndigits=2)
        max_fats = round((final_tdee * 0.3) / 9, ndigits=2)
        min_proteins = round((final_tdee * 0.15) / 4, ndigits=2)
        max_proteins = round((final_tdee * 0.2) / 4, ndigits=2)
        cholesterol = 200
        sodium = 2300

    elif health_issues == "Hypertension":
        min_carbs = round((final_tdee * 0.4) / 4, ndigits=2)
        max_carbs = round((final_tdee * 0.55) / 4, ndigits=2)
        min_fats = round((final_tdee * 0.25) / 9, ndigits=2)
        max_fats = round((final_tdee * 0.27) / 9, ndigits=2)
        min_proteins = round((final_tdee * 0.12) / 4, ndigits=2)
        max_proteins = round((final_tdee * 0.18) / 4, ndigits=2)
        cholesterol = 150
        sodium = 1500

    elif health_issues == "Hypotension":
        min_carbs = round((final_tdee * 0.4) / 4, ndigits=2)
        max_carbs = round((final_tdee * 0.55) / 4, ndigits=2)
        min_fats = round((final_tdee * 0.25) / 9, ndigits=2)
        max_fats = round((final_tdee * 0.27) / 9, ndigits=2)
        min_proteins = round((final_tdee * 0.18) / 4, ndigits=2)
        max_proteins = round((final_tdee * 0.2) / 4, ndigits=2)
        cholesterol = 200
        sodium = 2300

    else:
        min_carbs = round((final_tdee * 0.4) / 4, ndigits=2)
        max_carbs = round((final_tdee * 0.65) / 4, ndigits=2)
        min_fats = round((final_tdee * 0.2) / 9, ndigits=2)
        max_fats = round((final_tdee * 0.35) / 9, ndigits=2)
        min_proteins = round((final_tdee * 0.12) / 4, ndigits=2)
        max_proteins = round((final_tdee * 0.2) / 4, ndigits=2)
        cholesterol = 300
        sodium = 2300
    return min_carbs, max_carbs, min_fats, max_fats, min_proteins, max_proteins, cholesterol, sodium


def filter_recipes(recipe_df, max_fats_b, max_fats_l, max_fats_s, max_fats_d, max_carbs_b, max_carbs_l, max_carbs_s, max_carbs_d, max_proteins_b, max_proteins_l, max_proteins_s, max_proteins_d, cholesterol_b, cholesterol_l, cholesterol_s, cholesterol_d, sodium_b, sodium_l, sodium_s, sodium_d, num=2000, nrows=9999):

    lst_random_id = []
    for i in range(num):
        index = random.randint(0, (nrows - 1))
        lst_random_id.append(recipe_df._get_value(index, "id"))

    lst_fat_sum_b = []
    lst_fat_sum_l = []
    lst_fat_sum_s = []
    lst_fat_sum_d = []
    lst_selected_id_fat = []
    for i in lst_random_id:
        id_fat = int(recipe_df[recipe_df["id"] == i].fatContent.values)
        if id_fat < (max_fats_b  - sum(lst_fat_sum_b)):
            lst_fat_sum_b.append(id_fat)
            lst_selected_id_fat.append(i)
            pass
        elif id_fat < (max_fats_l  - sum(lst_fat_sum_l)):
            lst_fat_sum_l.append(id_fat)
            lst_selected_id_fat.append(i)
            pass
        elif id_fat < (max_fats_s  - sum(lst_fat_sum_s)):
            lst_fat_sum_s.append(id_fat)
            lst_selected_id_fat.append(i)
            pass
        elif id_fat < (max_fats_d  - sum(lst_fat_sum_d)):
            lst_fat_sum_d.append(id_fat)
            lst_selected_id_fat.append(i)
            pass
        else:
            pass
    print("\nBased on Fats {} recipe id's were selected.".format(len(lst_selected_id_fat)))
    
    
    lst_random_id = []
    for i in range(num):
        index = random.randint(0, (nrows - 1))
        lst_random_id.append(recipe_df._get_value(index, "id"))

    lst_carbs_sum_b = []
    lst_carbs_sum_l = []
    lst_carbs_sum_s = []
    lst_carbs_sum_d = []
    lst_selected_id_carbs = []
    for i in lst_random_id:
        id_carbs = int(recipe_df[recipe_df["id"] == i].carbohydrateContent.values)
        if id_carbs < (max_carbs_b  - sum(lst_carbs_sum_b)):
            lst_carbs_sum_b.append(id_carbs)
            lst_selected_id_carbs.append(i)
            pass
        elif id_carbs < (max_carbs_l  - sum(lst_carbs_sum_l)):
            lst_carbs_sum_l.append(id_carbs)
            lst_selected_id_carbs.append(i)
            pass
        elif id_carbs < (max_carbs_s  - sum(lst_carbs_sum_s)):
            lst_carbs_sum_s.append(id_carbs)
            lst_selected_id_carbs.append(i)
            pass
        elif id_carbs < (max_carbs_d  - sum(lst_carbs_sum_d)):
            lst_carbs_sum_d.append(id_carbs)
            lst_selected_id_carbs.append(i)
            pass
        else:
            pass
    print("\nBased on Carbs {} recipe id's were selected.".format(len(lst_selected_id_carbs)))
    
    
    lst_random_id = []
    for i in range(num):
        index = random.randint(0, (nrows - 1))
        lst_random_id.append(recipe_df._get_value(index, "id"))

    lst_proteins_sum_b = []
    lst_proteins_sum_l = []
    lst_proteins_sum_s = []
    lst_proteins_sum_d = []
    lst_selected_id_proteins = []
    for i in lst_random_id:
        id_proteins = int(recipe_df[recipe_df["id"] == i].proteinContent.values)
        if id_proteins < (max_proteins_b  - sum(lst_proteins_sum_b)):
            lst_proteins_sum_b.append(id_proteins)
            lst_selected_id_proteins.append(i)
            pass
        elif id_proteins < (max_proteins_l  - sum(lst_proteins_sum_l)):
            lst_proteins_sum_l.append(id_proteins)
            lst_selected_id_proteins.append(i)
            pass
        elif id_proteins < (max_proteins_s  - sum(lst_proteins_sum_s)):
            lst_proteins_sum_s.append(id_proteins)
            lst_selected_id_proteins.append(i)
            pass
        elif id_proteins < (max_proteins_d  - sum(lst_proteins_sum_d)):
            lst_proteins_sum_d.append(id_proteins)
            lst_selected_id_proteins.append(i)
            pass
        else:
            pass
    print("\nBased on Proteins {} recipe id's were selected.".format(len(lst_selected_id_proteins)))
    
    
    lst_random_id = []
    for i in range(num):
        index = random.randint(0, (nrows - 1))
        lst_random_id.append(recipe_df._get_value(index, "id"))

    lst_cholesterol_sum_b = []
    lst_cholesterol_sum_l = []
    lst_cholesterol_sum_s = []
    lst_cholesterol_sum_d = []
    lst_selected_id_cholesterol = []
    for i in lst_random_id:
        id_cholesterol = int(recipe_df[recipe_df["id"] == i].cholesterolContent.values)
        if id_cholesterol < (cholesterol_b  - sum(lst_cholesterol_sum_b)):
            lst_cholesterol_sum_b.append(id_cholesterol)
            lst_selected_id_cholesterol.append(i)
            pass
        elif id_cholesterol < (cholesterol_l  - sum(lst_cholesterol_sum_l)):
            lst_cholesterol_sum_l.append(id_cholesterol)
            lst_selected_id_cholesterol.append(i)
            pass
        elif id_cholesterol < (cholesterol_s  - sum(lst_cholesterol_sum_s)):
            lst_cholesterol_sum_s.append(id_cholesterol)
            lst_selected_id_cholesterol.append(i)
            pass
        elif id_cholesterol < (cholesterol_d  - sum(lst_cholesterol_sum_d)):
            lst_cholesterol_sum_d.append(id_cholesterol)
            lst_selected_id_cholesterol.append(i)
            pass
        else:
            pass
    print("\nBased on Cholesterol {} recipe id's were selected.".format(len(lst_selected_id_cholesterol)))
    
    
    lst_random_id = []
    for i in range(num):
        index = random.randint(0, (nrows - 1))
        lst_random_id.append(recipe_df._get_value(index, "id"))

    lst_sodium_sum_b = []
    lst_sodium_sum_l = []
    lst_sodium_sum_s = []
    lst_sodium_sum_d = []
    lst_selected_id_sodium = []
    for i in lst_random_id:
        id_sodium = int(recipe_df[recipe_df["id"] == i].sodiumContent.values)
        if id_sodium < (sodium_b  - sum(lst_sodium_sum_b)):
            lst_sodium_sum_b.append(id_sodium)
            lst_selected_id_sodium.append(i)
            pass
        elif id_sodium < (sodium_l  - sum(lst_sodium_sum_l)):
            lst_sodium_sum_l.append(id_sodium)
            lst_selected_id_sodium.append(i)
            pass
        elif id_sodium < (sodium_s  - sum(lst_sodium_sum_s)):
            lst_sodium_sum_s.append(id_sodium)
            lst_selected_id_sodium.append(i)
            pass
        elif id_sodium < (sodium_d  - sum(lst_sodium_sum_d)):
            lst_sodium_sum_d.append(id_sodium)
            lst_selected_id_sodium.append(i)
            pass
        else:
            pass
    print("\nBased on Sodium {} recipe id's were selected.".format(len(lst_selected_id_sodium)))
    
    lst_selected_id = lst_selected_id_carbs + lst_selected_id_fat + lst_selected_id_proteins + lst_selected_id_cholesterol + lst_selected_id_sodium
    print("\nTotal number of recipe id's we have got after joining is : ", len(lst_selected_id))
    
    """Removing Duplicates"""
    lst_final_recipe_id = []

    for i in lst_selected_id:
        if i not in lst_final_recipe_id:
            lst_final_recipe_id.append(i)
    print("\nTotal number of recipe id's we have got after dropping duplicates is : ", len(lst_final_recipe_id))
    
    """Getting All Values for each selected Id"""
    for i in range(0, len(lst_final_recipe_id)):
        if i == 0:
            lst_selected_recipes = recipe_df[recipe_df.id == lst_final_recipe_id[i]].values.tolist()
        else:
            lst_selected_recipes = lst_selected_recipes + recipe_df[recipe_df.id == lst_final_recipe_id[i]].values.tolist()
    
    
    selected_recipes_df = pd.DataFrame(lst_selected_recipes, columns=["ingredients", "url", "title", "id", "instructions", "nutrition", "calories", "fatContent", "saturatedFatContent", "cholesterolContent", "sodiumContent", "carbohydrateContent", "fiberContent", "sugarContent", "proteinContent"])
    return selected_recipes_df

# %%
def recommend_recipes(age, weight, height, gender, health_issues, activeness, goal, recipe_df, b, l, s, d):
    
    bmr, final_tdee = calculate_bmr_tdee(age, weight, height, gender, activeness, goal)
    min_carbs, max_carbs, min_fats, max_fats, min_proteins, max_proteins, cholesterol, sodium = calculate_nutritional_limits_day(final_tdee)
        
    # For Breakfast
    min_carbs_b = round(min_carbs * b, ndigits=2)
    max_carbs_b = round(max_carbs * b, ndigits=2)
    min_fats_b = round(min_fats * b, ndigits=2)
    max_fats_b = round(max_fats * b, ndigits=2)
    min_proteins_b = round(min_proteins * b, ndigits=2)
    max_proteins_b = round(min_proteins * b, ndigits=2)
    cholesterol_b = round(cholesterol * b, ndigits=2)
    sodium_b = round(sodium * b, ndigits=2)

    # For Lunch
    min_carbs_l = round(min_carbs * l, ndigits=2)
    max_carbs_l = round(max_carbs * l, ndigits=2)
    min_fats_l = round(min_fats * l, ndigits=2)
    max_fats_l = round(max_fats * l, ndigits=2)
    min_proteins_l = round(min_proteins * l, ndigits=2)
    max_proteins_l = round(min_proteins * l, ndigits=2)
    cholesterol_l = round(cholesterol * l, ndigits=2)
    sodium_l = round(sodium * l, ndigits=2)

    # For Snacks
    min_carbs_s = round(min_carbs * s, ndigits=2)
    max_carbs_s = round(max_carbs * s, ndigits=2)
    min_fats_s = round(min_fats * s, ndigits=2)
    max_fats_s = round(max_fats * s, ndigits=2)
    min_proteins_s = round(min_proteins * s, ndigits=2)
    max_proteins_s = round(min_proteins * s, ndigits=2)
    cholesterol_s = round(cholesterol * s, ndigits=2)
    sodium_s = round(sodium * s, ndigits=2)

    # For Dinner
    min_carbs_d = round(min_carbs * d, ndigits=2)
    max_carbs_d = round(max_carbs * d, ndigits=2)
    min_fats_d = round(min_fats * d, ndigits=2)
    max_fats_d = round(max_fats * d, ndigits=2)
    min_proteins_d = round(min_proteins * d, ndigits=2)
    max_proteins_d = round(min_proteins * d, ndigits=2)
    cholesterol_d = round(cholesterol * d, ndigits=2)
    sodium_d = round(sodium * d, ndigits=2)

    print("\n\nRecipe for User should have these ranges of Nutritional Facts only:\n")
    print("Carbohydrates:\nFor a Day -> {}g - {}g\nFor Breakfast -> {}g - {}g\nFor Lunch -> {}g - {}g\nFor Snacks -> {}g - {}g\nFor Dinner -> {}g - {}g\n\n".format(min_carbs, max_carbs, min_carbs_b, max_carbs_b, min_carbs_l, max_carbs_l, min_carbs_s, max_carbs_s, min_carbs_d, max_carbs_d))
    print("Fats:\nFor a Day -> {}g - {}g\nFor Breakfast -> {}g - {}g\nFor Lunch -> {}g - {}g\nFor Snacks -> {}g - {}g\nFor Dinner -> {}g - {}g\n\n".format(min_fats, max_fats, min_fats_b, max_fats_b, min_fats_l, max_fats_l, min_fats_s, max_fats_s, min_fats_d, max_fats_d))
    print("Proteins:\nFor a Day -> {}g - {}g\nFor Breakfast -> {}g - {}g\nFor Lunch -> {}g - {}g\nFor Snacks -> {}g - {}g\nFor Dinner -> {}g - {}g\n\n".format(min_proteins, max_proteins, min_proteins_b, max_proteins_b, min_proteins_l, max_proteins_l, min_proteins_s, max_proteins_s, min_proteins_d, max_proteins_d))
    print("Cholesterol:\nFor a Day - {}mg\nFor Breakfast - {}mg\nFor Lunch - {}mg\nFor Snacks - {}mg\nFor Dinner - {}mg\n".format(cholesterol, cholesterol_b, cholesterol_l, cholesterol_s, cholesterol_d))
    print("Sodium:\nFor a Day - {}mg\nFor Breakfast - {}mg\nFor Lunch - {}mg\nFor Snacks - {}mg\nFor Dinner - {}mg\n".format(sodium, sodium_b, sodium_l, sodium_s, sodium_d))
    
    selected_recipes_df = filter_recipes(recipe_df, max_fats_b, max_fats_l, max_fats_s, max_fats_d, max_carbs_b, max_carbs_l, max_carbs_s, max_carbs_d, max_proteins_b, max_proteins_l, max_proteins_s, max_proteins_d, cholesterol_b, cholesterol_l, cholesterol_s, cholesterol_d, sodium_b, sodium_l, sodium_s, sodium_d, num=2000, nrows=nrows-1)
    print("\nSelected Recipes DataFrame having {} rows & {} columns.".format(selected_recipes_df.shape[0], selected_recipes_df.shape[1]))
#     selected_recipes_df.head()
    
    print("\nMaximum Ranges of Nutrients under which all recipes to come:")
    print("Maximum Carbohydrates for a Meal - {}g\nMaximum Fats for a Meal - {}g\nMaximum Proteins for a Meal - {}g\nMaximum Cholesterol for a Meal - {}mg\nMaximum Sodium for a Meal - {}mg\n".format(max_carbs_l, max_fats_l, max_proteins_l, cholesterol_l, sodium_l))

    recommended_recipes_df = selected_recipes_df[(selected_recipes_df["fatContent"] < max_fats_l) & (selected_recipes_df["carbohydrateContent"] < max_carbs_l) & (selected_recipes_df["proteinContent"] < max_proteins_l) & (selected_recipes_df["cholesterolContent"] < cholesterol_l) & (selected_recipes_df["sodiumContent"] < sodium_l)]
    print("\nRecommended Recipes DataFrame having {} rows & {} columns.".format(recommended_recipes_df.shape[0], recommended_recipes_df.shape[1]))
    print("All Done Good")
    return recommended_recipes_df

# %%
"""Taking Inputs from Users"""

print("USER INPUTS:")
age = int(input("Age : "))
weight = int(input("Weight (in Kg) : "))
height = int(input("Height (in cm) : "))
gender = input("Gender {Male / Female} : ")
health_issues = input("Any Health Issues {Diabetes / Hypertension / Hypotension / None} : ")
activeness = input("Activeness Level {Sedentary / Lightly Active / Moderately Active / Very Active / Extra Active} : ")
goal = input("Lose Weight / Maintain Weight / Gain Weight : ")

"""Percentage of Calorie segregation in 4 Meal Plan"""

b = 0.3
l = 0.35
s = 0.1
d = 0.25

"""Let's get some Recipe's Recommendation"""

recommended_recipes_df = recommend_recipes(age, weight, height, gender, health_issues, activeness, goal, recipe_df, b, l, s, d)
# Out:
# USER INPUTS:
# Age : 25
# Weight (in Kg) : 79
# Height (in cm) : 180
# Gender {Male / Female} : Male
# Any Health Issues {Diabetes / Hypertension / Hypotension / None} : Diabetes
# Activeness Level {Sedentary / Lightly Active / Moderately Active / Very Active / Extra Active} : Sedentary
# Lose Weight / Maintain Weight / Gain Weight : Gain Weight
#
# User's BMR - 1795.0kcal & TDEE - 2154.0kcal
# Final TDEE - 2654.0kcal
#
#
# Recipe for User should have these ranges of Nutritional Facts only:
#
# Carbohydrates:
# For a Day -> 265.4g - 331.75g
# For Breakfast -> 79.62g - 99.52g
# For Lunch -> 92.89g - 116.11g
# For Snacks -> 26.54g - 33.18g
# For Dinner -> 66.35g - 82.94g
#
#
# Fats:
# For a Day -> 73.72g - 88.47g
# For Breakfast -> 22.12g - 26.54g
# For Lunch -> 25.8g - 30.96g
# For Snacks -> 7.37g - 8.85g
# For Dinner -> 18.43g - 22.12g
#
#
# Proteins:
# For a Day -> 99.52g - 132.7g
# For Breakfast -> 29.86g - 29.86g
# For Lunch -> 34.83g - 34.83g
# For Snacks -> 9.95g - 9.95g
# For Dinner -> 24.88g - 24.88g
#
#
# Cholesterol:
# For a Day - 200mg
# For Breakfast - 60.0mg
# For Lunch - 70.0mg
# For Snacks - 20.0mg
# For Dinner - 50.0mg
#
# Sodium:
# For a Day - 2300mg
# For Breakfast - 690.0mg
# For Lunch - 805.0mg
# For Snacks - 230.0mg
# For Dinner - 575.0mg
#
#
# Based on Fats 183 recipe id's were selected.
#
# Based on Carbs 68 recipe id's were selected.
#
# Based on Proteins 176 recipe id's were selected.
#
# Based on Cholesterol 456 recipe id's were selected.
#
# Based on Sodium 62 recipe id's were selected.
#
# Total number of recipe id's we have got after joining is :  945
#
# Total number of recipe id's we have got after dropping duplicates is :  762
#
# Selected Recipes DataFrame having 762 rows & 15 columns.
#
# Maximum Ranges of Nutrients under which all recipes to come:
# Maximum Carbohydrates for a Meal - 116.11g
# Maximum Fats for a Meal - 30.96g
# Maximum Proteins for a Meal - 34.83g
# Maximum Cholesterol for a Meal - 70.0mg
# Maximum Sodium for a Meal - 805.0mg
#
#
# Recommended Recipes DataFrame having 621 rows & 15 columns.
# All Done Good

# %%
recommended_recipes_df
# Out:
#                                            ingredients  \
# 0    [{'text': '8 boneless skinless chicken breasts...
# 3    [{'text': '34 cup butter'}, {'text': '14 ounce...
# 4    [{'text': '4 ounces cream cheese'}, {'text': '...
# 7    [{'text': '1 (9 ounce) boxjiffy golden yellow ...
# 10   [{'text': '1 (15 ounce) can refried beans'}, {...
# ..                                                 ...
# 756  [{'text': '3 tablespoons rolled oats (bulk sec...
# 757  [{'text': '1 tablespoon lavender flowers'}, {'...
# 758  [{'text': '30 ml Midori melon liqueur'}, {'tex...
# 759  [{'text': 'milk (says "ready-made")'}, {'text'...
# 760  [{'text': '12 lb unsalted butter'}, {'text': '...
#
#                                                    url  \
# 0    http://www.food.com/recipe/tangy-citrus-chicke...
# 3    http://www.food.com/recipe/chocolate-peanut-bu...
# 4    http://www.food.com/recipe/cream-cheese-seafoo...
# 7    http://www.food.com/recipe/christmas-santa-cup...
# 10   http://www.food.com/recipe/canadian-mexican-di...
# ..                                                 ...
# 756  http://www.food.com/recipe/easy-overnight-mues...
# 757   http://www.food.com/recipe/lavender-sugar-190508
# 758  http://www.food.com/recipe/sex-on-the-bridge-3...
# 759  http://www.food.com/recipe/hot-chocolate-made-...
# 760  http://www.food.com/recipe/maple-pecan-cookies...
#
#                                                  title          id  \
# 0                                 Tangy Citrus Chicken  02010fa63e
# 3           Chocolate Peanut Butter Butterscotch Fudge  0161a01cfd
# 4                        Cream Cheese & Seafood Spread  284f827a2a
# 7                             Christmas Santa Cupcakes  016933d1f6
# 10                                Canadian Mexican Dip  196f17b7e2
# ..                                                 ...         ...
# 756  Easy, Overnight Muesli - Strawberry Version (S...  1b324d3668
# 757                                     Lavender Sugar  02585c8c11
# 758                                  Sex on the Bridge  0091ff9f87
# 759                       Hot Chocolate Made With Milk  0219edad24
# 760                                Maple Pecan Cookies  1af1d8ad42
#
#                                           instructions  \
# 0    [{'text': 'Preheat oven to 350F.'}, {'text': '...
# 3    [{'text': 'Melt butter in a heavy saucepan ove...
# 4    [{'text': 'Spread softened cream cheese into t...
# 7    [{'text': 'Preheat oven to 350.'}, {'text': 'M...
# 10   [{'text': 'Mix the re-fried beans with half th...
# ..                                                 ...
# 756  [{'text': 'Before you go to bed, put the oats ...
# 757  [{'text': 'mix together and keep in a tightly ...
# 758  [{'text': 'Mix alcohol in a highball glass and...
# 759  [{'text': 'First, make your old favorite.'}, {...
# 760  [{'text': 'Preheat oven to 325F.'}, {'text': '...
#
#                                              nutrition  calories  fatContent  \
# 0    {'calories': '245.3', 'fatContent': '1.6', 'sa...     245.3         1.6
# 3    {'calories': '225.2', 'fatContent': '15.4', 's...     225.2        15.4
# 4    {'calories': '94.8', 'fatContent': '7', 'satur...      94.8         7.0
# 7    {'calories': '198', 'fatContent': '5.7', 'satu...     198.0         5.7
# 10   {'calories': '343.3', 'fatContent': '23.7', 's...     343.3        23.7
# ..                                                 ...       ...         ...
# 756  {'calories': '62.2', 'fatContent': '2.9', 'sat...      62.2         2.9
# 757  {'calories': '48.8', 'fatContent': '0', 'satur...      48.8         0.0
# 758  {'calories': '36.6', 'fatContent': '0', 'satur...      36.6         0.0
# 759  {'calories': '0', 'fatContent': '0', 'saturate...       0.0         0.0
# 760  {'calories': '55.1', 'fatContent': '4', 'satur...      55.1         4.0
#
#      saturatedFatContent  cholesterolContent  sodiumContent  \
# 0                    0.4                68.4           78.7
# 3                    6.1                10.8           57.5
# 4                    4.2                26.4          294.0
# 7                    1.0                31.9          292.4
# 10                   9.7                34.1          705.1
# ..                   ...                 ...            ...
# 756                  0.3                 0.0            1.3
# 757                  0.0                 0.0            0.0
# 758                  0.0                 0.0            0.3
# 759                  0.0                 0.0            0.0
# 760                  1.8                 9.4            0.6
#
#      carbohydrateContent  fiberContent  sugarContent  proteinContent
# 0                   30.6           0.2          29.8            27.5
# 3                   20.0           1.4          16.4             4.0
# 4                    3.4           0.0           0.0             4.8
# 7                   33.4           0.5          18.6             2.9
# 10                  22.4           8.7           2.7            13.5
# ..                   ...           ...           ...             ...
# 756                  9.2           1.2           5.5             1.0
# 757                 12.6           0.0          12.6             0.0
# 758                  0.9           0.2           0.6             0.1
# 759                  0.0           0.0           0.0             0.0
# 760                  4.5           0.3           1.8             0.6
#
# [621 rows x 15 columns]

# %% [markdown]
# # adding to subham's code

# %%
df = recommended_recipes_df.copy()

# %%
df.tail()
# Out:
#                                            ingredients  \
# 756  [{'text': '3 tablespoons rolled oats (bulk sec...
# 757  [{'text': '1 tablespoon lavender flowers'}, {'...
# 758  [{'text': '30 ml Midori melon liqueur'}, {'tex...
# 759  [{'text': 'milk (says "ready-made")'}, {'text'...
# 760  [{'text': '12 lb unsalted butter'}, {'text': '...
#
#                                                    url  \
# 756  http://www.food.com/recipe/easy-overnight-mues...
# 757   http://www.food.com/recipe/lavender-sugar-190508
# 758  http://www.food.com/recipe/sex-on-the-bridge-3...
# 759  http://www.food.com/recipe/hot-chocolate-made-...
# 760  http://www.food.com/recipe/maple-pecan-cookies...
#
#                                                  title          id  \
# 756  Easy, Overnight Muesli - Strawberry Version (S...  1b324d3668
# 757                                     Lavender Sugar  02585c8c11
# 758                                  Sex on the Bridge  0091ff9f87
# 759                       Hot Chocolate Made With Milk  0219edad24
# 760                                Maple Pecan Cookies  1af1d8ad42
#
#                                           instructions  \
# 756  [{'text': 'Before you go to bed, put the oats ...
# 757  [{'text': 'mix together and keep in a tightly ...
# 758  [{'text': 'Mix alcohol in a highball glass and...
# 759  [{'text': 'First, make your old favorite.'}, {...
# 760  [{'text': 'Preheat oven to 325F.'}, {'text': '...
#
#                                              nutrition  calories  fatContent  \
# 756  {'calories': '62.2', 'fatContent': '2.9', 'sat...      62.2         2.9
# 757  {'calories': '48.8', 'fatContent': '0', 'satur...      48.8         0.0
# 758  {'calories': '36.6', 'fatContent': '0', 'satur...      36.6         0.0
# 759  {'calories': '0', 'fatContent': '0', 'saturate...       0.0         0.0
# 760  {'calories': '55.1', 'fatContent': '4', 'satur...      55.1         4.0
#
#      saturatedFatContent  cholesterolContent  sodiumContent  \
# 756                  0.3                 0.0            1.3
# 757                  0.0                 0.0            0.0
# 758                  0.0                 0.0            0.3
# 759                  0.0                 0.0            0.0
# 760                  1.8                 9.4            0.6
#
#      carbohydrateContent  fiberContent  sugarContent  proteinContent
# 756                  9.2           1.2           5.5             1.0
# 757                 12.6           0.0          12.6             0.0
# 758                  0.9           0.2           0.6             0.1
# 759                  0.0           0.0           0.0             0.0
# 760                  4.5           0.3           1.8             0.6

# %% [markdown]
# # NLP starts

# %%
df.ingredients = df.ix[:,0]
# Out:
# <ipython-input-12-771e2921393a>:1: FutureWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#ix-indexer-is-deprecated
#   df.ingredients = df.ix[:,0]

# %%
df.ingredients
# Out:
# 0      [{'text': '8 boneless skinless chicken breasts...
# 3      [{'text': '34 cup butter'}, {'text': '14 ounce...
# 4      [{'text': '4 ounces cream cheese'}, {'text': '...
# 7      [{'text': '1 (9 ounce) boxjiffy golden yellow ...
# 10     [{'text': '1 (15 ounce) can refried beans'}, {...
#                              ...
# 756    [{'text': '3 tablespoons rolled oats (bulk sec...
# 757    [{'text': '1 tablespoon lavender flowers'}, {'...
# 758    [{'text': '30 ml Midori melon liqueur'}, {'tex...
# 759    [{'text': 'milk (says "ready-made")'}, {'text'...
# 760    [{'text': '12 lb unsalted butter'}, {'text': '...
# Name: ingredients, Length: 621, dtype: object

# %%
df.head()
# Out:
#                                           ingredients  \
# 0   [{'text': '8 boneless skinless chicken breasts...
# 3   [{'text': '34 cup butter'}, {'text': '14 ounce...
# 4   [{'text': '4 ounces cream cheese'}, {'text': '...
# 7   [{'text': '1 (9 ounce) boxjiffy golden yellow ...
# 10  [{'text': '1 (15 ounce) can refried beans'}, {...
#
#                                                   url  \
# 0   http://www.food.com/recipe/tangy-citrus-chicke...
# 3   http://www.food.com/recipe/chocolate-peanut-bu...
# 4   http://www.food.com/recipe/cream-cheese-seafoo...
# 7   http://www.food.com/recipe/christmas-santa-cup...
# 10  http://www.food.com/recipe/canadian-mexican-di...
#
#                                          title          id  \
# 0                         Tangy Citrus Chicken  02010fa63e
# 3   Chocolate Peanut Butter Butterscotch Fudge  0161a01cfd
# 4                Cream Cheese & Seafood Spread  284f827a2a
# 7                     Christmas Santa Cupcakes  016933d1f6
# 10                        Canadian Mexican Dip  196f17b7e2
#
#                                          instructions  \
# 0   [{'text': 'Preheat oven to 350F.'}, {'text': '...
# 3   [{'text': 'Melt butter in a heavy saucepan ove...
# 4   [{'text': 'Spread softened cream cheese into t...
# 7   [{'text': 'Preheat oven to 350.'}, {'text': 'M...
# 10  [{'text': 'Mix the re-fried beans with half th...
#
#                                             nutrition  calories  fatContent  \
# 0   {'calories': '245.3', 'fatContent': '1.6', 'sa...     245.3         1.6
# 3   {'calories': '225.2', 'fatContent': '15.4', 's...     225.2        15.4
# 4   {'calories': '94.8', 'fatContent': '7', 'satur...      94.8         7.0
# 7   {'calories': '198', 'fatContent': '5.7', 'satu...     198.0         5.7
# 10  {'calories': '343.3', 'fatContent': '23.7', 's...     343.3        23.7
#
#     saturatedFatContent  cholesterolContent  sodiumContent  \
# 0                   0.4                68.4           78.7
# 3                   6.1                10.8           57.5
# 4                   4.2                26.4          294.0
# 7                   1.0                31.9          292.4
# 10                  9.7                34.1          705.1
#
#     carbohydrateContent  fiberContent  sugarContent  proteinContent
# 0                  30.6           0.2          29.8            27.5
# 3                  20.0           1.4          16.4             4.0
# 4                   3.4           0.0           0.0             4.8
# 7                  33.4           0.5          18.6             2.9
# 10                 22.4           8.7           2.7            13.5

# %%
import ast
lst = []
for i in df.ingredients:
    res = ast.literal_eval(i)
    #lst.append(res)
    lst.append(res)

# %%
df['ingredients'] = lst

# %%
df.ingredients
# Out:
# 0      [{'text': '8 boneless skinless chicken breasts...
# 3      [{'text': '34 cup butter'}, {'text': '14 ounce...
# 4      [{'text': '4 ounces cream cheese'}, {'text': '...
# 7      [{'text': '1 (9 ounce) boxjiffy golden yellow ...
# 10     [{'text': '1 (15 ounce) can refried beans'}, {...
#                              ...
# 756    [{'text': '3 tablespoons rolled oats (bulk sec...
# 757    [{'text': '1 tablespoon lavender flowers'}, {'...
# 758    [{'text': '30 ml Midori melon liqueur'}, {'tex...
# 759    [{'text': 'milk (says "ready-made")'}, {'text'...
# 760    [{'text': '12 lb unsalted butter'}, {'text': '...
# Name: ingredients, Length: 621, dtype: object

# %%
for i in df.ingredients.index:
    lst = []
    ing = df.ingredients[i]
    for ingred in ing:
        ingredients_text = ingred['text']
        print(ingredients_text)
        lst.append(ingredients_text)
        l = ' '.join(lst)
        df.ingredients[i] = l
# Out:
# 8 boneless skinless chicken breasts
# 1 (6 ounce) can frozen lemonade concentrate, thawed
# 12 cup honey
# 1 teaspoon rubbed sage
# 12 teaspoon ground mustard
# 12 teaspoon dried thyme
# 12 teaspoon lemon juice
# 34 cup butter
# 14 ounces sweetened condensed milk
# 3 tablespoons milk
# 1 (12 ounce) package semi-sweet chocolate chips
# 1 (12 ounce) package milk chocolate chips
# 1 (12 ounce) package peanut butter chips
# 1 cup butterscotch chips
# 1 (7 ounce) jar marshmallow cream
# 1 12 teaspoons vanilla extract
# 12 teaspoon almond extract
# 1 lb walnuts, coarsely chopped
# 4 ounces cream cheese
# 12 cup purchased seafood sauce
# 6 ounces imitation crabmeat, shredded (pollack)
# assorted cracker, to serve
# 1 (9 ounce) boxjiffy golden yellow cake mix
# 1 teaspoon almond extract
# 1 egg
# 12 cup water
# 1 tablespoon red food coloring
# 1 (15 ounce) can refried beans
# 1 packet taco seasoning or 1 packet chili seasoning mix
# 12 cup sour cream
# 2 teaspoons mayonnaise
# 2 avocados
# 1 teaspoon lemon juice
# 1 clove of crushed garlic
# 2 cups grated cheese (or more)
# 2 finely diced tomatoes (or more)
# 2 chopped spring onions (or more)
# corn chips
# 1 cup brewed coffee
# 2 -4 tablespoons half-and-half or 2 -4 tablespoons heavy cream
# 2 tablespoons Nesquik no-sugar-added chocolate powder
# 1 (15 ounce) can butter beans
# 14 cup brown sugar
# 2 tablespoons butter
# 2 fresh mozzarella balls
# 3 tablespoons yoghurt
# 1 lemon
# 2 teaspoons dried marjoram
# 1 red chile
# 1 teaspoon olive oil
# 1 sweet onion (medium)
# 2 tablespoons soy sauce
# 1 teaspoon Worcestershire sauce
# 12 cup chopped yellow bell pepper
# 12 cup chopped red bell pepper
# 12 cup chopped green bell pepper
# 1 -2 tablespoon butter
# 1 lb white button mushrooms
# 18 teaspoon garlic salt
# fresh ground pepper
# 2 tablespoons butter
# 2 tablespoons chopped onions
# 12 lb mushroom, sliced
# 2 (10 ounce) packagesfrozen peas, thawed and drained
# 1 tablespoon fresh lemon juice
# 14 teaspoon salt
# 18 teaspoon pepper
# 1 lb hot sausage
# 1 lb mild sausage
# 1 12 cups Jiffy baking mix or 1 12 cups Bisquick
# 12 cup milk
# 8 ounces sharp cheddar cheese
# 8 ounces mild cheddar cheese
# 1 lemon wedge
# sugar, for the coating rims of glasses
# 1 12 ounces calvados
# 12 ounce orange liqueur, such as Cointreau
# 1 tablespoon fresh lemon juice
# 4 medium size mushrooms, thinly sliced
# 2 tablespoons butter
# 1 tablespoon flour
# 1 12 cups beef stock
# 2 tablespoons mushroom soy sauce
# 1 tablespoon red wine
# 1 pinch sugar, if needed
# salt and pepper
# 12 cup vegetable oil
# 14 cup red wine vinegar
# 12 teaspoon salt
# 12 teaspoon pepper
# 12 teaspoon dried parsley
# 12 teaspoon dried basil
# 14 teaspoon sugar
# 18 teaspoon dried oregano
# 18 teaspoon garlic powder
# 18 teaspoon onion powder
# 18 teaspoon Mrs. Dash seasoning mix
# 18 teaspoon lemon juice
# 1 (3 ounce) packet Top Ramen noodles (not instant, any flavor)
# 1 bouillon cube (try to match with flavor of ramen)
# 2 -3 dashes tabasco hot habanero sauce
# salt and pepper
# 1 gallon apple cider
# 12 teaspoon whole allspice
# 12 teaspoon whole cloves
# 1 dash nutmeg
# 3 cinnamon sticks (3 inch)
# 2 tablespoons butter
# 14 teaspoon chili powder
# 14 teaspoon black pepper
# 18 teaspoon garlic powder
# 18 teaspoon red pepper (optional)
# 2 tablespoons butter
# 1 teaspoon cornstarch
# 14 cup chicken broth
# 6 eggs
# 14 cup milk
# 12 teaspoon basil
# 1 -2 tablespoon onion flakes or 14 cup sauteed onion
# salt, pepper to taste
# 12-1 cup shrimp or 12-1 cup crabmeat or 12-1 cup ham or 12-1 cup bacon or 12-1 cup broccoli or 12-1 cup mushroom, whichever you prefer
# 1 cup grated cheddar cheese or 1 cup swiss cheese
# 3 tablespoons vegetable oil
# 12 cup popcorn
# 6 tablespoons butter, melted
# 1 cup pecorino romano cheese, grated
# 1 teaspoon coarseley ground pepper
# 1 cup labneh (thick strained yogurt cheese)
# 14 teaspoon ground allspice
# 1 12 teaspoons aleppo pepper, plus more for serving
# salt, if needed, and freshly ground black pepper
# olive oil, to drizzle
# 1 (3 1/2 ounce) package achiote paste
# 3 chipotle peppers, canned with adobo sauce, plus
# 4 tablespoons adobo sauce, from the canned chipotles
# 14 cup vegetable oil or 14 cup olive oil
# 34 cup water
# 13 cup olive oil
# 3 tablespoons balsamic vinegar
# 2 teaspoons Dijon mustard
# salt & freshly ground black pepper
# 8 cups apple cider
# 12 black peppercorns, crushed
# 8 whole allspice
# 2 bay leaves
# 1 vanilla bean, 3 inch piece, split lengthwise and scraped
# 1 lemon rind, 2 by 1/2 inch strip
# 11 ounces tube refrigerated breadstick dough
# 14 cup butter, melted
# 2 tablespoons cinnamon sugar
# 1 large egg, slightly beaten
# 48 sliced natural almonds (with skin)
# 2 beets
# 13 cup goat's cheese
# 16 slices prosciutto
# 1 teaspoon olive oil
# salt and pepper
# 1 cup crushed shortbread cookie
# 2 tablespoons butter, melted
# 14 teaspoon cinnamon
# 14 cup lemon curd
# 8 ounces low-fat cream cheese
# 6 ounces sugar-free non-fat vanilla yogurt
# 1 teaspoon vanilla extract
# 3 tablespoons artificial sweetener, i.e. Splenda
# 1 ounce vodka (30ml)
# 12 ounce coconut rum (15ml)
# 12 ounce peach schnapps (15ml)
# orange juice
# 12 teaspoon basil leaves
# 12 teaspoon rosemary
# 12 teaspoon thyme leaves
# 12 teaspoon oregano leaves
# 1 teaspoon parsley
# 1 pinch salt
# 1 lb butter, at room temperature (salted or unsalted, I use a butter spread to cut down on calories)
# 2 fresh garlic cloves or 1 tablespoon instant minced garlic
# 2 tablespoons lemon juice (concentrate)
# 2 jiggers golden rum
# 2 dashes Angostura bitters
# 1 teaspoon simple syrup
# 1 teaspoon water
# 1 slice orange peel
# cubed ice
# 4 -5 pieces of leftover cake like cornbread
# 12-1 cup vegetable oil, melted lard or 12-1 cup olive oil
# maple syrup
# 2 12 teaspoons essential oils (in any combination of the the oils listed in the introduction)
# 1 cup Everclear alcohol (190-proof grain alcohol available in liquor stores)
# water
# salt (optional)
# 14 cup hydrogen peroxide
# 2 gallons water
# 2 cups all-purpose flour
# 1 teaspoon baking powder
# 12 teaspoon baking soda
# 12 teaspoon salt
# 12 teaspoon ground cinnamon
# 12 cup butter, softened
# 34 cup brown sugar, packed
# 2 eggs
# 2 medium bananas, ripe & mashed (about 1 cup)
# 14 cup sour cream
# 1 teaspoon vanilla extract
# 1 cup walnuts, chopped & toasted
# 2 tablespoons pillsbury chocolate cake mix
# 1 tablespoon yoplait light vanilla yogurt
# butter, for dish
# 12 small soft shelled crabs, cleaned
# salt
# pepper
# flour
# 6 tablespoons butter
# 2 tablespoons oil
# 2 ounces dry whole wheat spaghetti
# 1 ounce lowfat mozzarella cheese, diced
# 1 medium diced red bell pepper (can also use a green pepper)
# 1 teaspoon dried basil (or 2 tbsp. thinly sliced fresh basil)
# 1 teaspoon extra virgin olive oil
# 12 teaspoon balsamic vinegar
# garlic salt
# 1 teaspoon olive oil
# 1 small onion, diced
# 6 tablespoons butter
# 2 tablespoons fresh dill, snipped
# 1 teaspoon sugar
# salt & pepper
# 1 loaf French bread
# 1 lb sweet Italian sausage, broken into bite size pieces
# 1 lb red potatoes, sliced 1/4-inch thick (use small ones)
# 34 cup onion, diced
# 6 slices bacon
# 1 12 teaspoons garlic, minced
# 2 cups kale, cut in half and then sliced thinly
# 3 teaspoons chicken base
# 6 cups water
# 12 cup evaporated milk
# 1 cup pure wild rice
# 4 cups water
# 14 cup Grand Marnier
# 2 tablespoons salted butter, softened
# 2 leeks, white parts only-chopped into fine slices
# 4 turkey hot dogs or 4 other hot dogs, your preference
# 4 hot dog buns or 4 hamburger buns
# 1 tablespoon butter, softened
# assorted condiments
# 60 ml Canadian Club whisky
# 60 ml peppermint schnapps
# 60 ml Amaretto
# 12 cup reduced-fat ricotta cheese
# 2 tablespoons grated parmesan cheese
# 12 cup chopped mushroom
# 12 cup diced roasted red pepper
# 1 egg
# 2 egg whites
# 12 teaspoon dried basil
# 14 teaspoon kosher salt (to taste)
# 18 teaspoon fresh ground black pepper (to taste)
# 12 ounce Kahlua
# 12 ounce vodka
# whipped cream
# 4 lbs venison chuck roast
# bottled Italian salad dressing
# 14 cup soy sauce
# 4 garlic cloves, sliced
# 1 large onion, sliced thinly
# 1 12 cups all-purpose flour
# 34 cup Splenda granular
# 2 tablespoons baking powder
# 1 teaspoon baking soda
# 12 teaspoon salt
# 23 cup dannon low-fat plain yogurt or 23 cup nonfat plain yogurt
# 23 cup skim milk
# 12 cup blueberries or 12 cup grated apple
# 2 lbs shark
# 1 teaspoon baking powder
# 1 cup flour
# 1 cup water
# 1 tablespoon white vinegar
# 1 12 teaspoons salt
# oil (for frying)
# 2 ounces light rum
# 14 ounce triple sec
# 12 ounce lime juice
# 12 teaspoon superfine sugar
# 12 egg white
# mint leaf
# 3 ounces apricot nectar
# 2 ounces pineapple juice
# 1 ounce lime juice (Fresh)
# 1 ounce cherry syrup
# ice (few pieces optional)
# 1 cup beef bouillon granules
# 12 teaspoon pepper
# 1 cup dry onion, minced
# 14 cup onion powder
# 14 cup parsley flakes
# 18 cup onion salt
# nonstick cooking spray
# 2 medium potatoes, but into 1/8 inch thick slices
# 14 teaspoon garlic salt
# 1 medium tomatoes, chopped, about 2/3 cup
# 2 teaspoons snipped fresh basil
# 18 teaspoon salt
# 2 medium fresh portabella mushrooms, each about 4 inches in diameter
# 1 teaspoon balsamic vinegar or 1 teaspoon red wine vinegar
# 12 teaspoon olive oil
# 12 loaf focaccia bread, quartered or 12 Italian bread, such as boboli brand
# finely shredded parmesan cheese (optional)
# 1 12 cups light coconut milk (do not use coconut cream)
# 1 12 cups pineapple juice, chilled
# 12 teaspoon vanilla
# 2 tablespoons sugar
# 18 teaspoon ground nutmeg
# 3 ice cubes
# 3 medium ripe bananas, frozen
# toasted shredded sweetened coconut (optional)
# whipped cream (optional)
# 1 12 cups nonfat milk
# 1 34 teaspoons sugar-free lemonade-flavored drink mix (such as crystal light)
# 1 cup plain fat-free yogurt
# 12 teaspoon vanilla extract
# 1 cup frozen blueberries
# 1 cup balsamic vinegar
# 2 tablespoons brown sugar
# 3 medium cucumbers, peeled and thinly sliced
# 1 medium red onion, thinly sliced
# 12 cup white distilled vinegar
# 3 tablespoons sugar
# 14 teaspoon ground ginger
# 1 tablespoon chopped chives
# 18 teaspoon dried oregano
# 1 teaspoon salt
# 14 teaspoon pepper
# 12 cup chopped red pepper
# 14 cup part-skim ricotta cheese
# 14 cup fat free sour cream
# 1 large garlic clove, crushed
# 1 teaspoon basil
# 14 teaspoon salt
# 14 teaspoon pepper
# 12 cup chopped and seeded plum tomato
# 4 large hot baked potatoes, cut in half
# 10 regular tea bags
# 1 cup sugar or 12 cup maple syrup
# 1 gallon glass container
# ice cube, cubes from 2 trays
# 12 cup cayenne pepper
# 14 cup black pepper, freshly ground
# 14 cup white pepper, freshly ground
# 14 cup thyme, crushed
# 14 cup rosemary
# 3 tablespoons marjoram
# 2 tablespoons chipotle peppers, freshly ground
# 2 tablespoons sea salt
# 2 tablespoons oregano
# 1 tablespoon garlic powder
# 1 tablespoon gumbo file, ground fine
# 24 orange slice candy
# 24 small green gumdrops
# 2 lbs thin-skinned potatoes, scrubbed (1 to 1 1/2 in. wide)
# 1 cup cocktail onion (to taste)
# 1 lb raclette cheese (see notes)
# 1 cup cornichon pickle (to taste)
# salt and pepper
# 3 fluid ounces light rum
# 1 fluid ounce lime juice
# 1 teaspoon sugar (bar sugar works best since it disolves quickly)
# orange juice
# 2 medium zucchini
# 12 cup egg substitute (Egg Beaters) or 2 eggs
# 12 cup onion (chopped)
# 34 cup dry breadcrumbs
# 1 teaspoon salt
# 1 teaspoon garlic powder
# 1 lb fresh green beans, cleaned and snipped
# 1 ripe mango, sliced 1/4 inch thick
# 4 cups baby greens
# 2 tablespoons prepared raspberry vinaigrette dressing
# 2 lbs yellowtail fish fillets, scaled and fileted, skin left on
# 5 garlic cloves, chopped
# 2 large onions, sliced in rings
# kosher salt
# 1 cup vinegar
# 12 cup water
# 12 cup brown sugar
# 8 peppercorns
# 4 cloves
# 4 allspice berries
# 2 bay leaves
# 1 tablespoon masala (curry powder)
# 2 teaspoons ground cumin
# 2 teaspoons ground coriander
# 1 teaspoon turmeric
# oil, as needed for frying
# 1 (750 ml) bottle white wine (pinot grigio or sauvignon blanc, something dry)
# 2 (10 ounce) bottles apple juice
# 34 cup peach schnapps
# 12 cup citrus-infused vodka
# splash lemon juice
# artificial sweetener (I used splenda)
# 1 navel orange
# 2 peaches, peeled (or can use frozen peaches)
# 1 cup white grapes, halved
# 1 golden delicious apple, peeled
# ice
# 1 cup forbidden black rice
# 2 12 cups water or 2 12 cups broth
# 14 teaspoon salt
# 1 (19 ounce) can garbanzo beans (Drain beans and process in food processor or blender, adding just enough juice to make smooth and cr)
# 3 cups celery, finely chopped
# 1 medium cucumber, peeled, seeded and finely diced
# 12 cup chopped green onion
# 2 minced garlic cloves
# 1 cup chopped fresh cilantro or 1 cup parsley
# 12 teaspoon sugar
# 1 tablespoon vinegar
# 1 teaspoon cumin
# 1 teaspoon oregano
# 1 tablespoon Tabasco sauce
# 2 tablespoons fresh lime juice
# 2 (10 ounce) cansdiced tomatoes and green chilies
# 10 medium size chicken pieces
# 1 bunch coriander leaves
# 8 garlic cloves
# 6 green chilies
# 4 teaspoons of thick plain low-fat yogurt
# salt
# butter
# 3 cardamoms
# 1 cinnamon stick
# 4 cloves
# 14 teaspoon cumin
# 1 lb dry black beans
# 6 cups water
# 1 teaspoon salt
# 12 teaspoon ground black pepper
# 14 teaspoon cumin
# 14 teaspoon onion powder
# 12 teaspoon garlic powder
# 1 bay leaf
# 14 cup tequila rose strawberry cream liqueur
# 12 cup strawberry margarita mix
# 34 cup 7-Up soda (or Club Soda)
# 18 cup tequila (optional)
# 3 ounces brandy (2 measures (typically KEO VSOP or Haggipavlu Anglias brands)
# 1 12 ounces lemon cordial, to taste (1 measure)
# 2 -4 drops bitters (Angostura or Cypriot Cock Drops brands)
# lemonade or soda water
# ice
# 1 head romanesco (stem and clusters intact, leaves removed)
# 8 -10 small cherry tomatoes (amount is my guess) or 8 -10 red grape tomatoes, cut in half (amount is my guess)
# 1 star fruit
# raw sugar
# 600 g potatoes (use large potatoes)
# olive oil, to taste
# sea salt, to taste
# 1 cup sweet vermouth, chilled
# 12 pint lemon sorbet
# orange peel (to garnish)
# 34 cup canned mango, slices
# 34 ounce grenadine
# 14 cup orange juice
# 1 cup ice
# 6 apples, cored and sliced
# 1 cup sugar
# 14 cup turbinado sugar
# 12 cup honey, heated
# 1 cup dried cranberries
# 1 cup apple juice
# 1 tablespoon fresh lemon juice
# 1 teaspoon mulling spices
# 750 ml vodka
# 1 cup apple juice
# 1 cup cake flour
# 1 12 cups superfine sugar
# 1 14 cups egg whites, at room temperature (about 10 large egg whites)
# 1 14 teaspoons cream of tartar
# 14 teaspoon salt
# 1 teaspoon vanilla extract
# 1 teaspoon grated lemon zest
# 1 cup frozen blueberries or 1 cup fresh blueberries
# 12 lemon, juice of
# sugar (2 to 4 tablespoons, to taste)
# 1 medium jicama, peeled and cut into 1/4-inch strips
# 3 large oranges, peeled, seeded, and sectioned
# 1 medium purple onion, thinly sliced and separated into rings
# 1 cup orange juice
# 14 cup lime juice
# 1 teaspoon ground coriander
# lettuce leaf
# 1 lime, thinly sliced
# 1 large ripe watermelon
# vodka (use as much as you need)
# 8 pineapple rings
# 12 cup brown sugar
# 1 shallot
# 3 blood oranges
# 1 12 teaspoons balsamic vinegar
# 12 teaspoon red wine vinegar
# extra virgin olive oil
# salt and pepper
# 1 12 lbs asparagus (25-30 spears)
# 1 ounce espresso
# 1 12 ounces vanilla vodka
# 1 12 ounces Kahlua
# 1 ounce Creme de Cacao
# 2 cups white grape juice
# 1 cup diet lemon-lime soda
# 2 tablespoons Splenda sugar substitute, if desired
# 40 lollipop sticks
# 40 large marshmallows, 1 10-oz bag
# 1 12 cups crushed graham crackers
# 1 (1 lb) bag chocolate-flavored candy coating
# 1 (20 ounce) can pineapple chunks, juice drained and reserved
# 1 (3 1/2 ounce) package vanilla instant pudding mix
# 14 cup orange breakfast drink mix, dry
# 1 (11 ounce) can mandarin oranges, drained
# 1 (16 ounce) can fruit cocktail, drained
# 2 bananas, sliced
# 2 apples or 2 pears, cut into chunks
# 1 cup sliced fresh strawberries (optional)
# 1 calf's head, skinned
# 4 calf feet, skinned
# 1 gallon water
# 2 small onions
# 3 cloves
# 1 cup white wine vinegar
# 1 teaspoon peppercorn
# 3 bay leaves
# 12 lemon, cut into small pieces
# 2 tablespoons salt
# 3 eggs, hard cooked, peeled and chopped
# 3 -4 jalapeno peppers, chopped,seeded if desired,to taste
# 1 medium onion, chopped,as desired
# 1 -2 clove garlic, minced
# 1 bunch fresh cilantro leaves, chopped,according to your preference (I like lots!)
# 1 -2 tablespoon fresh lime juice
# 1 -2 tomatillo, peeled,washed,and chopped (optional)
# 1 (4 -8 ounce) canchopped mild green chili peppers, to taste,with or without brine
# 1 (28 ounce) can whole tomatoes, coarsely chopped,with juice
# salt & freshly ground black pepper
# 1 small pineapple, peeled
# 34 cup sugar
# 34 cup water
# 2 tablespoons orange blossom water (or 1 tsp orange extract) or 2 tablespoons rose water (or 1 tsp orange extract)
# 1 cup unsweetened coconut cream
# 2 tablespoons unsweetened coconut cream, for topping
# crushed ice (optional)
# 1 quart vanilla ice cream (optional)
# mint sprig, for garnish
# 3 -4 tomatoes (I usually use 1 large red, and 2-3 smaller orange, yellow, or green)
# 12 red onion (halved through the stem)
# 12 yellow sweet onion
# 12 cucumber
# 1 fresh mozzarella ball
# fresh ground black pepper
# chives or fresh basil
# 350 g brown sugar
# 170 g golden syrup
# 125 g butter, cut into pieces
# 1 tablespoon white wine vinegar
# 125 ml water
# 2 tablespoons vanilla essence
# 3 12 lbs pike (any fish will do) or 3 12 lbs pickerel, cleaned and scaled (any fish will do)
# water, just to cover
# 14 cup vinegar
# 12 teaspoon onion juice
# 1 teaspoon salt
# 4 gingersnaps
# 12 cup brown sugar
# 14 cup raisins
# 1 lemon, thinly sliced
# 4 tablespoons cornflour (cornstarch)
# 600 ml skim milk
# 2 tablespoons caster sugar
# 12 teaspoon vanilla essence
# 1 (410 g) canww apricot halves, drained and pureed
# 2 ounces Intrigue liqueur
# 1 ounce grapefruit juice
# 1 ounce club soda
# 6 ounces pineapple juice
# 1 (1/4 ounce) package dry yeast
# 3 cups flour
# 12 cup warm skim milk
# 12 cup egg substitute
# 13 cup Splenda sugar substitute
# 14 cup unsweetened applesauce
# 12 teaspoon salt
# cooking spray
# 2 quarts vegetable broth
# 1 cup Quaker quick barley
# 2 large carrots
# 2 stalks celery
# 1 onion
# 1 (14 1/2 ounce) can diced tomatoes
# 1 zucchini
# 1 teaspoon salt
# 12 teaspoon pepper
# 1 teaspoon paprika
# 1 teaspoon curry
# 1 teaspoon parsley flakes
# 1 teaspoon garlic powder
# 1 teaspoon sugar
# 3 bay leaves
# 1 medium onion (chopped )
# 14 cup water
# 1 green bell pepper (chopped )
# 1 red bell pepper (chopped )
# 30 ounces canned black beans (rinsed )
# 2 cups chopped tomatoes ((fresh or canned)
# 2 teaspoons jamaican jerk spice (more to taste)
# 1 teaspoon grated gingerroot ((fresh)
# salt (to taste)
# 1 (15 ounce) can great northern beans, drained and rinsed
# 1 (15 ounce) can red beans, drained and rinsed
# 5 teaspoons garlic, minced
# 1 large onion, chopped
# 1 cup carrot, thinly sliced
# 12 cup celery, thinly sliced
# 2 cups green beans, fresh, cleaned and cut
# 2 red chili peppers, chopped (remove as many or as little seeds depending on how much heat you want)
# 2 bay leaves
# salt and pepper, to taste
# 4 kiwi fruits
# 1 (6 ounce) can lemonade concentrate (thawed)
# 2 cups water
# 8 (3/4 ounce) packetsof alpine diet sugar-free apple cider mix, single serving
# 2 cups diet ocean spray reduced-calorie cranberry juice cocktail
# cold water
# ice
# 2 ounces roasted barley (1/4 cup)
# 1 12 pints water
# honey, can be added to help sooth sore throat
# lemon, can be added to help sooth sore throat
# standing rib roast (trimmed weight about 10 to 10 1/2 pounds, 4-ribs)
# 1 tablespoon black peppercorns, ground coarse
# 2 teaspoons dried green peppercorns, ground coarse
# 1 teaspoon white peppercorns, ground coarse
# 4 whole allspice, ground coarse
# 12 teaspoon dried thyme
# 1 teaspoon coarse salt
# 34 lb baby carrots, peeled, trimmed, blanched in boiling salted water for 4 minutes, and refreshed under cold water
# 1 head garlic, separated into cloves, blanched in boiling water for 5 minutes, refreshed under cold water, and peel
# 12 lb large shallot, blanched in boiling water for 3 minutes, refreshed under cold water, and peeled
# 12 cup dry red wine
# 2 cups canned beef broth
# 6 tablespoons madeira wine
# 1 tablespoon arrowroot
# 2 tablespoons dijon-style mustard
# fresh thyme sprig (to garnish)
# 1 cup dried cherries
# 2 tablespoons kirsch
# 1 12 cups all-purpose flour
# 12 cup cocoa powder
# 1 teaspoon baking powder
# 12 teaspoon salt
# 2 large beaten eggs
# 1 cup granulated sugar
# 2 teaspoons vanilla extract
# 1 lb fish fillet, white saltwater (albacore, sole, snapper, halibut anything you would see on a sushi menu)
# 1 cup lime juice, key limes if you can get them
# 12 cup lemon juice
# 12 cup orange juice
# 1 tablespoon salt
# 1 rocoto chilies (chile manzano in Mexican markets) or 2 aji amarillo chilies (substitute a habanero)
# 1 medium onion, sliced very thinly into half-moons
# 4 tablespoons cilantro, chopped
# 12 cup cake flour
# 12 cup unsweetened cocoa powder
# 14 teaspoon baking powder
# 14 teaspoon salt
# 14 cup Egg Beaters egg substitute
# 2 large egg whites
# 34 cup artificial sweetener
# 12 cup unsweetened applesauce
# 3 teaspoons vanilla extract
# 2 tablespoons walnuts (optional)
# 1 cup water
# 1 cup light soymilk
# 3 ounces sugar-free red Jell-O
# 1 (750 ml) bottle vodka (cheap brands are okay, the cucumber is all you taste anyway)
# 1 large cucumber, peeled, seeded, and diced
# 1 large cucumber, scored and sliced into rounds
# 1 (20 ounce) bottle cranberry juice
# 1 12 cups water
# 1 12 cups sugar
# 1 cup lemon juice (preferably not from concentrate)
# 1 cup lime juice (preferably not from concentrate)
# 1 ounce Cointreau liqueur
# 3 ounces vodka
# 3 cups rose wine
# 1 cup cranberry juice
# 1 cup lemon soda
# 1 cup fresh cranberries
# 1 cup honeydew melon, diced (or in balls)
# ice
# 750 ml sparkling wine (such as Champagne)
# 150 ml berry liqueur (such as creme de cassis)
# 150 g caster sugar
# 1 14 cups vodka, well chilled
# 2 12 cups cranberry juice, well chilled
# 1 14 cups grapefruit juice, well chilled
# 1 lime, thinly sliced
# 16 spring roll wrappers
# 4 whole bananas, cut into quarters lengthwise
# 4 tablespoons sugar
# 1 teaspoon cinnamon (optional)
# canola oil, for deep-frying
# 34 cup sugar
# 12 cup water
# 1 cup fresh cold lime juice
# 1 lime, zested
# 2 12 cups cold water
# 14 cup tequila
# crushed ice
# lime wedge, for garnish
# seasoning, mix (onion, celery, red/green/yellow bell pepper - diced, as much as you like, but go easy, too much will)
# 1 jar pimiento
# 1 lb shrimp (can use canned, frozen or fresh - peel fresh if using)
# 1 lb bay scallop (the small ones)
# 1 lb lump crabmeat
# 12 cup mayonnaise
# 1 tablespoon Dijon mustard
# Tony Chachere's Seasoning, to taste
# half-and-half
# breadcrumbs
# parmesan cheese
# 1 egg
# fresh parsley
# 2 large lemons
# 6 slightly underripe pears
# 3 cups cold water
# 1 cup sugar
# 12 inch vanilla bean
# thin strips orange zest
# grand marnier custard, sauce (recipe is in my cookbook)
# 4 cups ripe peeled and diced bartlett pears
# 3 cups cranberries (or frozen )
# 2 cups raspberries (or frozen )
# 2 12 cups sugar
# 23 cup orange juice
# 1 tablespoon orange zest
# 1 teaspoon ground ginger
# 12 teaspoon ground cinnamon
# 14 teaspoon ground nutmeg
# 14 teaspoon ground allspice
# 14 teaspoon ground cloves
# 4 tablespoons orange liqueur
# 1 wrap, whole wheat fat free (8 or 10 inch)
# 2 tablespoons Boar's Head Pepperhouse Gourmaise
# 12 cup romaine lettuce, shredded
# 6 slices Boar's Head Ovengold Roasted Breast of Turkey, thinly sliced
# 2 tablespoons bath soap (liquid castile soap is best)
# 14 cup honey
# 14 cup rose water or 14 cup mineral water
# 4 ounces honey
# 2 teaspoons nutmeg, freshly grated
# 5 vanilla beans, scraped
# 3 cloves
# 1 bunch of fresh mint
# 6 peppercorns, whole
# 2 lemons, zest of
# 2 oranges, zest of
# 2 liters vodka (the better the vodka, the better the taste)
# 2 cups macaroni, cooked to directions and draine
# 14 cup bacon
# 4 cups tomatoes or 4 cups tomato juice
# 12 diced onion, cooked- (optional)
# 14 cup diced jalapeno
# 1 teaspoon dried chili (optional)
# 2 12 quarts strawberries
# 3 cups water, divided
# 2 inches lemon peel, pith removed
# 2 12 cups sugar
# 3 12 cups corn syrup
# 2 tablespoons fresh lemon juice
# 3 cups orange juice
# 1 (30 ml) caneagle brand sweetened condensed milk
# 14 cup lemon juice
# 10 paper cups (5oz size)
# 10 wooden sticks
# 14 ounce banana syrup
# 14 ounce hazelnut syrup
# 14 ounce caramel syrup
# 2 ounces hot espresso
# 1 teaspoon banana syrup
# hot steamed milk (or foamed)
# hazelnut powder, for topping
# 3 -4 egg whites
# 18 cup diced tomato
# 18 cup diced green pepper
# 18 cup diced mushroom
# 14 cup low-fat Mexican cheese blend
# 3 tablespoons mild salsa
# pepper
# ms. dash sodium-free seasoning (or Generic Equivalent)
# 32 ounces Simply Potatoes Garlic Mashed Potatoes
# 5 ounces grated asiago cheese
# 5 ounces fat free sour cream
# 2 teaspoons onion powder
# 12 teaspoon fresh ground black pepper
# 1 bag garlic
# olive oil
# baking parchment paper
# 5 strawberries
# 1 grapefruit
# 12 medium papaya
# 14 cup ice
# 4 cups rhubarb
# 14 cup white sugar
# 14 cup corn syrup
# 14 cup brown sugar
# 14 cup blood orange juice
# 1 cup water
# 14 cup sugar
# 1 bag fresh cranberries
# 34 cup dried apricot, snipped
# 13 cup orange marmalade
# orange zest, , if desired (to garnish)
# 6 cups skim milk, divided
# 8 ounces Egg Beaters egg substitute
# 12 cup Splenda granular, sugar substitute (or more to taste)
# 1 teaspoon vanilla
# 1 teaspoon rum extract
# 14 cup brandy (optional)
# 1 tablespoon whipped cream (optional)
# ground nutmeg (garnish) (optional)
# ground cinnamon (garnish) (optional)
# 1 lb wax bean, trimmed
# 1 tablespoon honey
# 1 lime, juice and zest of
# salt
# 4 teaspoons raw honey
# 13 teaspoon powdered ginger or 1 teaspoon grated fresh ginger
# 1 clove, bud
# 18 teaspoon cayenne (or Citrus fruits, Garlic, Onion, Oregano, Rosemary, Thyme)
# 18 teaspoon cinnamon (or Anise, Cayenne, Lemon, Thyme)
# 1 chayote
# salt
# pepper
# 5 ounces vodka (2 1/2 shots)
# 5 ounces gin
# 5 ounces dark rum
# 5 ounces triple sec
# 2 12 ounces lemon juice concentrate
# 20 ounces Coca-Cola (2 1/2 c.)
# 20 ounces orange juice
# 12 ounces frozen apple juice concentrate
# 36 ounces club soda (fill juice can 3 times)
# 4 cups watermelon, frozen
# 1 cup lemon- lime-flavored seltzer water
# 2 tablespoons Splenda sugar substitute
# 12 lemon
# 12 cup sugar
# 1 cup pomegranate juice
# 500 ml fresh cranberries
# 1 lb navy beans, Dry
# 3 quarts water
# 1 ham bone, Smoked or 1 hock (Smoked)
# 2 tablespoons parsley, Chopped
# 1 cup onion, Finely Chopped
# 1 clove garlic, Minced
# 2 cups celery & tops, Finely Chopped
# 1 12 teaspoons salt
# 12 teaspoon pepper
# 1 cup sugar
# 34 cup water, divided
# 1 teaspoon vanilla
# 1 pinch salt
# 13 cup tequila
# 13 cup triple sec
# 3 tablespoons orange juice
# 2 tablespoons lime juice
# 4 tablespoons pomegranate juice
# 2 twists fresh lime peel
# 1 (4 1/2 ounce) can shrimp, drained
# 1 (6 ounce) can crabmeat, drained and picked over
# 1 (6 ounce) can minced clams, drained
# 1 cup diced celery
# 34 cup diced green pepper
# 1 cup mayonnaise
# 1 tablespoon Worcestershire sauce
# 1 teaspoon lemon juice
# 2 drops hot pepper sauce
# crushed potato chips
# 2 tablespoons water
# 2 tablespoons fish sauce
# 14 cup white wine vinegar or 14 cup rice vinegar
# 2 tablespoons sugar (or to taste)
# 2 tablespoons chopped green onions
# 2 tablespoons chopped cilantro
# 1 tablespoon lime juice
# 1 teaspoon lime zest
# 1 teaspoon minced mint (optional) or 1 teaspoon lemon verbena (optional)
# 3 ounces white rum
# 3 ounces coconut rum
# 3 ounces apricot brandy
# 3 tablespoons grenadine
# 3 cups pineapple juice
# 4 pieces pineapple, spears
# 2 tablespoons garam masala
# 2 tablespoons ground cumin
# 1 tablespoon coriander powder
# 4 teaspoons paprika (or Kashmiri Mirch)
# 2 teaspoons kasuri methi or 2 teaspoons dried fenugreek leaves, crushed
# 1 teaspoon turmeric
# 12 teaspoon cayenne pepper (or Indian chilli powder)
# 1 ounce creme de banane
# 1 ounce blue curacao
# 3 ounces white cranberry juice
# 1 slice banana
# 1 23 ounces white rum
# 5 -6 mint leaves
# 23 ounce lime juice
# 1 dash gomme syrup
# 2 ounces vodka
# 1 ounce espresso, cooled (or really strong coffee)
# 12 ounce Kahlua
# ice
# whipped cream (optional)
# malted milk balls (optional)
# 4 Rice Krispies treats
# 4 fruit roll-ups (not fruit by the foot)
# 4 gummy worms or 4 swedish fish
# 3 quarts cooked and peeled small beets
# 1 12 cups water
# 3 12 cups cider vinegar
# 2 cinnamon sticks
# 2 cups sugar
# 1 teaspoon whole allspice
# 1 teaspoon salt
# 6 -8 ounces your favorite brand gold tequila
# 3 ounces triple sec (hiram walker, 2 shots)
# 3 12 cups ice
# margarita salt (optional)
# 2 12 cups margarita mix
# 1 lime, sliced (garnish)
# 2 teaspoons paprika
# 1 12 teaspoons ground black pepper
# 1 14 teaspoons salt
# 12 teaspoon dark brown sugar
# 14 teaspoon garlic powder
# 14 teaspoon onion powder
# 14 teaspoon ground cayenne pepper
# 1 lb dried beans (your favorite)
# 10 cups water
# 3 cups cooked black-eyed peas
# 1 small onion, quartered
# 2 tablespoons minced fresh parsley
# 1 garlic clove, minced
# 12 teaspoon salt
# 14 teaspoon ground cumin
# 18 teaspoon cayenne
# 18 teaspoon dried oregano
# 1 12 tablespoons red wine vinegar
# 1 (12 ounce) package frozen unsweetened strawberries
# 13 cup light corn syrup
# 14-13 cup white rum
# 2 tablespoons fresh lime juice
# 12 ripe honeydew melon, seeded and flesh cut into 1/2-inch cubes
# lime slice
# 1 large garlic clove
# 1 teaspoon Dijon mustard
# 3 tablespoons soy sauce
# 2 cups dry sherry
# 4 large salmon steaks
# 1 (89 ounce) container orange juice
# 1 (2 liter) bottle ginger ale, chilled
# 1 (46 ounce) can pineapple juice, chilled
# orange slice (to garnish) (optional)
# 14 cup fresh apple cider (not apple juice)
# 14 cup champagne
# 4 ounces vodka
# 12 ounce triple sec or 12 ounce flavored orange liqueur
# 2 ounces blood orange juice
# 2 slices blood oranges
# ice
# 14 teaspoon salt
# 14 teaspoon pepper
# 14 teaspoon sage
# boneless pork loin roast (single loin)
# 1 (16 ounce) can whole berry cranberry sauce or 1 (16 ounce) can jellied cranberry sauce
# 12 teaspoon finely shredded orange rind
# 13 cup orange juice
# 14 teaspoon sage
# 3 bananas, ripe
# 2 cups rolled oats
# 13 cup applesauce
# 1 teaspoon vanilla extract
# 1 tablespoon ground flax seeds (the program keeps putting in the word SEEDS. I didn't put that in)
# 12 cup dried cherries
# 1 can sliced beet, drain and save liquid
# 1 tablespoon cornstarch
# 14 teaspoon salt
# 12 cup cider vinegar
# 1 ounce vodka (optional)
# 14 cup sugar
# 1 12 ounces tequila
# 1 ounce peach schnapps
# 1 ounce blue curacao
# 4 ounces sour mix
# 40 pieces peppermint candies (see description)
# 12 ounces orange juice
# 12 ounces triple sec
# 9 ounces vodka
# 9 ounces Amaretto (see recipe description for alternatives)
# 9 ounces Southern Comfort
# 9 ounces gin
# 3 ounces grenadine
# 600 -700 g pumpkin, chopped into chunks (about 2 inches each way)
# 200 ml water
# 3 tablespoons sugar
# 3 tablespoons Japanese soy sauce
# 34 cup salsa
# 1 (19 ounce) can cannellini beans, rinsed and drained
# 1 teaspoon lemon juice
# 1 teaspoon dark brown chili powder
# 1 teaspoon ground cumin
# 18 teaspoon salt
# 2 ounces swedish punsch liqueur
# 12 lemon, juice
# soda water, to taste
# 1 teaspoon grenadine
# 4 cups cold water
# 2 cups sugar
# 1 (3 ounce) package gelatin (I prefer cherry)
# 1 (12 ounce) can frozen lemonade concentrate
# 1 (46 ounce) can pineapple juice
# 1 (2 liter) bottle ginger ale
# 5 apples, peeled, cored and thinly sliced
# 2 teaspoons lemon juice
# 14 cup brown sugar
# 14 teaspoon salt
# 1 teaspoon cinnamon
# 14 teaspoon nutmeg
# 4 lbs apples
# 1 cup bergamot leaf
# sugar
# 2 tablespoons pan drippings or 2 tablespoons oil
# 2 cups water
# 1 small onion
# 1 small green pepper
# 1 -2 garlic clove
# 2 tablespoons cornstarch
# 4 tablespoons cold water
# 250 g mascarpone, at room temperature
# 100 g smoked salmon, finely chopped
# <ipython-input-18-faf336e4e1ab>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.ingredients[i] = l
# 1 tablespoon lime juice
# 1 small red onion, grated
# 1 tablespoon capers, finely chopped
# 2 teaspoons horseradish cream
# 14 cup flat leaf parsley, finely chopped
# 2 tablespoons fresh dill, finely chopped
# 1 tablespoon cracked black pepper
# 4 carrots
# 12 cup raisins
# 12 cup pineapple chunk
# 1 tablespoon honey
# 1 tablespoon lime juice
# 12 teaspoon fresh grated ginger
# 1 tablespoon chopped fresh basil
# 1 cup white wine vinegar
# 1 cup sherry wine
# 6 roma tomatoes, seeded and chopped
# 10 green onions, chopped
# 2 fresh jalapeno peppers, seeded and chopped
# 14 cup chopped fresh cilantro
# 2 tablespoons fresh lime juice
# 2 tablespoons hot pepper sauce
# 1 teaspoon ground black pepper
# 1 teaspoon garlic powder
# 1 teaspoon salt
# 1 cup self raising flour (5)
# 1 teaspoon ground ginger
# 12 teaspoon baking soda
# 14 teaspoon ground cinnamon
# 3 tablespoons low-fat margarine (6)
# 1 12 tablespoons brown sugar (1 1/2)
# 3 teaspoons clear honey (3)
# 2 cups dry masa harina (corn tortilla mix)
# water
# oil, for frying (oil suitable for high heat)
# 1 cup of crushed ice
# 1 12 cups blackberries
# 1 nectarines or 1 peach
# 1 -2 teaspoon sugar
# 1 (6 ounce) container strawberry-banana yogurt
# 10 ounces corn tortilla chips (thick, sturdy ones)
# 2 cups shredded cooked chicken
# 1 (28 ounce) can tomatoes, drained
# 2 -3 tablespoons TABASCO brand Chipotle Pepper Sauce (I've used the adobo sauce from canned chipotles, not much difference in taste)
# 1 tablespoon vegetable oil
# 1 small onion, sliced 1/4 inch thick
# 2 garlic cloves, minced
# 1 12 cups chicken broth
# 12 teaspoon salt (omit if chips are very salty)
# 14 cup fresh cilantro, chopped
# 1 cup shredded monterey jack cheese (or a combo) or 1 cup monterey jack pepper cheese (or a combo) or 1 cup chihuahua cheese (or a combo)
# 1 lb waffle pretzel
# 1 (10 ounce) bag Hershey candy cane kisses
# 12 cup brown sugar, firmly packed
# 12 cup honey, local raw is best
# 14 cup water
# 1 tablespoon butter
# 1 teaspoon vanilla
# 14 cup finely minced onion
# 1 lb lean ground beef
# 34 cup fresh breadcrumb
# 1 egg, beaten
# 1 teaspoon salt
# 14 teaspoon ground pepper
# 1 tablespoon flour
# 1 cup orange juice
# 1 12 teaspoons lemon juice
# 14 cup drambuie
# 14 cup honey
# 1 orange, sliced (for garnish)
# 2 eggplants, large
# 14 teaspoon salt
# 2 cups flour
# 12 teaspoon baking powder
# 1 teaspoon ground cumin
# 1 teaspoon ground coriander
# 1 teaspoon chili powder (ground chiles, not the mix you use to make chili)
# 1 12 cups water
# 1 tablespoon vegetable oil
# 14 cup fresh lime juice
# 14 cup olive oil
# 2 teaspoons sugar
# 12 teaspoon salt
# 14 teaspoon hot pepper sauce
# 4 oranges
# 1 large jicama, peeled and julienned (about 3 cups)
# 2 medium cucumbers, peeled, sliced into rounds (about 3 cups)
# 1 medium red onion, thinly sliced
# 1 cup cilantro leaf, coarsely chopped
# 12-1 fresh jalapeno chile, finely chopped (use half red and half green)
# 4 medium apples, peeled and diced to 1/2-inch pieces
# 1 cup raisins
# 1 cup water
# 1 cup sugar
# 1 orange rind, grated and juiced
# 34 cup brown sugar
# 1 teaspoon cinnamon
# 12 teaspoon nutmeg
# 12 teaspoon ground cloves
# 1 tablespoon extract, brandy or 1 tablespoon rum
# 2 pie crusts
# 1 cup basmati rice or 1 cup brown rice
# 12 red onion (peeled, diced)
# 2 carrots (peeled, diced)
# 1 leek (diced)
# 1 stalk celery (trimmed, diced)
# 12 cup whole sweet corn (kernels)
# 14 teaspoon garlic powder
# 14 teaspoon curry powder
# 2 tablespoons extra virgin olive oil or 2 tablespoons vegetable oil
# 2 cups water (or more)
# 1 teaspoon teriyaki sauce (optional)
# 2 cups vegetable stock
# rosemary or thyme or parsley
# salt and black pepper
# 12 cup dates, pitted and cut in half
# 12 cup dried apricot, cut in half
# 1 apple, unpeeled, cored and diced
# 12 teaspoon ground allspice
# 12 cup chopped walnuts
# 12 cup chopped mushroom
# 1 tablespoon olive oil
# 1 lb baby bok choy, cut into bit-size pieces
# 2 garlic cloves, minced
# 14 cup chicken broth or 14 cup vegetable broth
# 18 teaspoon pepper
# 600 g frozen green beans or 600 g frozen yellow beans
# 30 ml vegetable oil
# 125 ml chicken broth
# 1 red onion, chopped
# 1 red pepper, chopped
# 60 ml olive oil
# 30 ml lemon juice
# 2 ml lemon peel, grated
# 10 ml dried oregano
# 10 ml minced garlic cloves
# 5 ml Dijon mustard
# salt and pepper
# 125 ml crumbled goat cheese
# 12 lb orzo pasta
# coarse salt
# 1 tablespoon olive oil
# 2 large lemons, zest of
# black pepper
# 14 cup parsley, chopped
# 8 flat anchovies
# 4 garlic cloves
# 2 large raw egg yolks or 3 large hard-boiled egg yolks
# 13 cup fresh lemon juice
# 2 tablespoons Dijon mustard
# 1 tablespoon red wine vinegar
# 1 dash Tabasco sauce
# 1 dash Worcestershire sauce
# 1 cup extra virgin olive oil
# 1 (3 lb) box frozen meatballs (or can make your own)
# 2 cups barbecue sauce (I use Miss Diana)
# 1 12 cups maple syrup
# 2 cups pineapple (I used fresh but can substitute canned)
# 1 green pepper (cut up)
# 2 garlic cloves (cut each into 4 pieces)
# 3 ounces cream cheese
# 2 tablespoons butter
# 1 lb powdered sugar
# 14 teaspoon peppermint extract
# 4 eggs, large
# 1 cup Crisco
# 2 cups sugar
# 1 tablespoon orange extract
# 1 cup milk
# 1 tablespoon distilled white vinegar
# 6 12 cups flour
# 2 teaspoons baking powder
# 3 teaspoons baking soda
# 1 cup cocoa powder
# 1 12 teaspoons nutmeg
# 1 12 teaspoons cinnamon
# 1 12 teaspoons cloves
# 1 12 teaspoons orange rind, grated
# 1 cup walnuts, coarsley chopped
# 1 cup raisins
# 1 lb powdered sugar, unsifted
# 12 cup egg white, room temperature
# 1 teaspoon cream of tartar
# 12 cup extra virgin olive oil
# 3 tablespoons apple cider vinegar or 3 tablespoons white wine vinegar
# 1 tablespoon sugar
# 12 cup dried cranberries, coarsely chopped
# 12 teaspoon salt
# 14 teaspoon fresh ground black pepper
# 8 cups greens, rinsed and dried (mezclun)
# 2 ripe bartlett pears, cored and thinly sliced (about 2 1/2 cups)
# 3 tablespoons fresh lemon juice
# 1 large kohlrabi (shredded or thinly sliced)
# 14 cup dried cranberries
# 14 cup goat cheese or 14 cup blue cheese, crumbled
# 2 ounces vanilla royale liqueur
# 1 ounce banana liqueur
# 1 12 ounces Canadian rye whisky
# 2 ounces simple syrup
# 1 ounce lemon juice
# 1 ounce lime juice
# 1 cup softened butter or 1 cup margarine
# 1 cup white sugar
# 1 teaspoon vanilla
# 1 egg yolk
# 12 cup sour cream
# 3 12 cups flour
# 1 cup orange juice, fresh squeezed Cara Cara and Blood Oranges
# 12 cup orange-infused vodka
# 14 cup orange-flavored liqueur
# 2 tablespoons simple syrup
# 1 cup butter, softened
# 2 cups confectioners' sugar
# 1 teaspoon vanilla extract
# scant 1 5/8 cups all-purpose flour, plus extra for dusting
# 12 teaspoon salt
# 58 cup pecan halves or 58 cup walnut halves, toasted and chopped very finely
# 2 cups water
# 2 cups vinegar
# 1 tablespoon mixed pickling spices
# 2 medium garlic cloves, chopped
# 2 -3 slices fresh ginger
# 1 lemon, thinly sliced
# 2 onions, thinly sliced
# salmon
# rock salt
# 1 12 ounces tequila
# 1 ounce triple sec
# 12 ounce fresh lime juice
# 12 ounce fresh orange juice
# 12 ounce fresh grapefruit juice
# Chambord raspberry liquor (black raspberry liqueur)
# 16 dried ghost chilies (I use fresh) or 16 habaneros
# 1 bell pepper (red, orange or yellow)
# 2 (28 ounce) cans diced tomatoes with juice
# 1 medium onion
# 4 garlic cloves
# 14 cup cider vinegar
# 2 tablespoons sugar
# 18 ounces sugar-free chocolate syrup, Sorbee is fat free and hardens well
# 50 strawberries, washed, trimmed, and frozen
# 1 lb rectangle shaped queso fresco (I like the one from Costco)
# 10 ounces bagel chips or 10 ounces crostini or 10 ounces crackers
# 5 ounces raspberry jelly or 5 ounces blackberry jelly or 5 ounces apricot jam or 5 ounces pepper jelly
# 1 cup no-sugar-added nonfat lemon yogurt (8 oz. container)
# 1 tablespoon lemon juice
# 3 packets sugar substitute
# cantaloupe, cut to bite size
# 2 (1 ounce) semi-sweet chocolate baking squares, chopped
# 14 cup butter, softened
# 13 cup brown sugar
# 14 cup sugar
# 1 egg
# 12 teaspoon vanilla
# 1 cup all-purpose gluten-free flour
# 3 tablespoons cocoa powder
# 14 teaspoon baking soda
# 18 teaspoon salt
# 36 gluten-free pretzel sticks (I used Glutino's)
# 1 bunch fresh cilantro, chopped including stems
# 3 jalapenos (this will be very hot, remove seeds or use less to taste)
# 1 garlic clove
# 12 teaspoon salt (or to taste)
# 14 cup olive oil
# 3 tablespoons mayonnaise
# 13 cup water
# splash lemon juice
# 12 cup Miracle Whip
# 18 cup balsamic vinegar
# 1 tablespoon red wine vinegar
# 1 -2 garlic clove (large)
# 1 prepared chocolate wafer pie crust (like Oreo)
# 1 (12 ounce) bag mint chocolate chips
# 1 (56 ounce) container chocolate marshmallow ice cream
# 1 (8 ounce) container chocolate Cool Whip
# 16 fresh basil leaves
# 4 tablespoons simple syrup
# 10 ounces vodka
# 1 lemon, juice of
# 8 ice cubes
# 1 chilled pear, half
# 1 red-hot candies
# 1 raisins, cut in half
# 2 slivered almonds, pieces
# 1 scoop cottage cheese or 1 scoop marshmallows
# curly leaf lettuce
# 1 12 tablespoons olive oil
# sea salt or kosher salt
# fresh ground black pepper
# 4 filet mignon, 1 1/2 inches thick
# 1 large garlic clove, quartered
# 2 ounces brandy or 2 ounces cognac
# 3 tablespoons unsalted butter
# 3 tablespoons fresh parsley, chopped
# 1 (15 ounce) can peach slices, drained and chopped
# 1 cup crushed pineapple, drained
# 2 tablespoons cornstarch
# 12 teaspoon cinnamon
# 1 pinch clove
# 13 cup frozen orange juice concentrate, slighty thawed
# 1 cup water
# 13 cup raisins
# 12 cup maraschino cherry, left whole or sliced in half (optional)
# 10 medjool dates
# 14 cup soft cheese (see note above)
# 1 tablespoon butter
# 14 cup chopped walnuts
# 14 cup maple syrup
# 100 g butter (soft but not melted)
# 14 cup sugar or 14 cup honey
# 1 14 cups stoneground flour (if you shift the flour you can use just the bran for a different texture to the biscuits) or 1 14 cups stoneground natural bran (if you shift the flour you can use just the bran for a different texture to the biscuits)
# 3 teaspoons baking powder
# 12 teaspoon salt
# 2 cups mayonnaise (Duke's is the best!)
# 12 cup brown mustard
# 2 teaspoons pickle juice
# 2 teaspoons ketchup
# 2 teaspoons Worcestershire sauce
# 1 chipotle pepper (canned)
# 1 teaspoon adobo sauce, from the canned chipotle pepper
# 2 garlic cloves, peeled
# 14 cup fresh parsley
# 1 pint jaboticabas, washed
# water
# 1 tablespoon honey
# 12 ounces bag cranberries, picked over (float them in a large bowl or pan, those that sink should be disgarded)
# 12 cup honey
# 3 tablespoons brown sugar, firmly packed (or to taste)
# 2 cinnamon sticks (1/4-1/2 teaspoon ground cinnamon)
# 6 whole cloves (1/4 teaspoon ground cloves)
# 14 teaspoon nutmeg, freshly grated (or to taste)
# 12 teaspoon ginger, freshly grated
# 1 tablespoon orange zest
# 34 cup orange juice
# 2 egg whites, beaten stiff
# 1 cup sugar
# 12 cup chocolate chips
# 12 teaspoon vanilla
# 12 teaspoon salt
# 1 12 cups corn flakes, crushed
# 12 cup shredded coconut
# 4 inches gingerroot, peeled & coarsely chopped
# 34 cup sugar
# 1 14 cups hot water
# 14 teaspoon lemon extract
# 34 liter cold sparkling water
# 2 (3 ounce) packages cream cheese
# 3 tablespoons light cream
# 1 tablespoon mayonnaise
# 12 teaspoon paprika
# 14 teaspoon salt
# 3 garlic cloves, finely cut (optional)
# 1 teaspoon Worcestershire sauce
# 2 teaspoons fresh lemon juice
# 1 teaspoon prepared mustard
# corn chips
# 15 -20 solo plastic cups (3 oz. size) or 15 -20 dixie brand paper cups (3 oz. size)
# ribbon (1 roll, satin or curling)
# 1 tablespoon dried marjoram
# 1 tablespoon dried basil
# 2 teaspoons garlic powder
# 2 teaspoons dried thyme
# 1 teaspoon dried rosemary, crushed
# 34 teaspoon dried oregano
# 34 lb saltine crackers (3 sleeves)
# 1 cup canola oil
# 2 (1 ounce) packagesoriginal dry ranch dressing mix
# 1 (1 ounce) packagefiesta dry ranch dressing mix
# 1 teaspoon crushed red pepper flakes
# 1 large parsnip, peeled
# 1 tablespoon vegetable oil
# salt, to taste
# 12 ounce Captain Morgan's spiced rum
# 12 ounce gin
# 12 ounce vodka
# 12 ounce tequila
# 12 ounce Cointreau liqueur or 12 ounce triple sec
# 1 12 ounces fresh lime juice
# 3 ounces guava nectar (such as Kearns)
# 3 ounces club soda (or to taste)
# ice, to serve
# lime wedge, to garnish
# 3 cups seeded cubed watermelon
# 13 cup sugar
# 13 cup freshly squeezed lime juice
# 12 cup light rum
# mint leaf (to garnish)
# 1 egg white, room temperature
# 18 teaspoon salt
# 1 cup packed brown sugar
# 1 tablespoon all-purpose flour
# 18 teaspoon cinnamon
# 1 teaspoon vanilla extract
# 1 12 cups chopped toasted pecans
# 2 (1 1/2 liter) bottles red wine, such as pinot noir, zinfandel, malbec, shiraz
# 12 gallon of cranberry pomegranate juice, cranberry raspberry juice, etc. (organic if possible)
# 1 orange, sliced
# spices, clove and cinnamon for sure, but nutmeg, ginger, allspice, cake spice or pumpkin pie spice, can also be added
# 2 -3 cinnamon sticks
# 30 ml Midori melon liqueur
# 30 ml malibu coconut rum
# 22 12 ml peach schnapps
# orange juice
# pineapple juice
# 2 tablespoons walnuts or 2 tablespoons pecans
# 14 cup Splenda sugar substitute
# 6 -8 medium baking apples, cored, but left whole and unpeeled
# 1 teaspoon cinnamon
# 2 tablespoons butter
# 12 cup water
# 8 cups ginger ale
# 14 cup orange juice
# 12 cup strawberry soda
# 1 cup Sprite
# 12 cup grapes
# 1 cup strawberry
# 1 tablespoon chocolate chips
# 14 cup mango juice
# 12 cup peach
# 1 tablespoon liquor (optional)
# 12 cup ice
# 2 ounces tequila
# 1 ounce st-germain liqueur
# 34 ounce freshly squeezed lime juice
# 12 cup salad oil
# 14 cup vinegar
# 1 small onion, chopped
# 1 teaspoon salt
# 1 dash pepper
# 2 teaspoons Worcestershire sauce
# 2 lbs meat
# 1 -2 black tea bags (recommend Constant Comment)
# 1 sprig of fresh mint, 8-10 leaves
# 2 -3 slices orange rind
# 2 ounces freshly squeezed lemonade
# 1 ounce white cranberry juice
# orange peel, spiral (to garnish)
# maraschino cherries or fresh cranberries (to garnish)
# 2 cups sugar
# 34 cup evaporated milk
# 2 ounces unsweetened chocolate, chopped
# 2 tablespoons light corn syrup
# 2 tablespoons butter
# 14 teaspoon salt
# 12 cup chopped nuts (optional)
# 1 teaspoon vanilla
# 7 ounces caramels
# 14 cup mini marshmallows
# 13 cup whipping cream
# 2 teaspoons rum
# 1 pumpkin or 1 hubbard squash
# water
# 1 cup butter
# 1 cup sifted confectioners' sugar
# 1 egg
# 1 12 teaspoons almond flavoring or 34 teaspoon peppermint extract
# 1 teaspoon vanilla extract
# 1 12 cups all-purpose flour
# 1 teaspoon salt
# 12 cup crushed peppermint candy
# 12 cup white sugar
# 1 (750 ml) bottleinexpensive fruity medium-bodied red wine
# 1 (750 ml) bottle coconut rum (I use Captain Morgan)
# 1 large fresh orange
# 1 fresh lime
# 1 fresh lemon
# 5 fresh kiwi
# 1 lb green grape
# 1 fresh mango
# 1 lb fresh strawberries
# 8 ounces semisweet chocolate, chopped fine or use good quality chips
# 1 teaspoon vegetable oil (I use walnut oil)
# 2 teaspoons instant coffee powder
# 1 12 cups unsalted nuts (use anykind, it's all good)
# 16 ounces cherry frosting
# 2 12 cups confectioners' sugar
# 10 ounces maraschino cherries
# 1 cup semi-sweet chocolate chips
# 3 tablespoons Crisco shortening
# 1 small onion, finely chopped
# 12 cup fresh mushrooms, sliced
# 12 teaspoon butter
# 1 garlic clove, minced
# 1 cup chicken breast, cooked & cubed
# 12 cup roasted sweet red pepper, chopped
# 1 tablespoon honey mustard
# 14 teaspoon salt
# 14 teaspoon lemon-pepper seasoning
# 14 teaspoon italian seasoning
# 14 teaspoon basil
# 2 c.swiss cheese, shredded
# 12 frozen yeast dinner roll dough, thawed
# 2 tablespoons butter, melted
# 1 (12 ounce) can pina colada nonalcoholic drink mix
# 3 kiwi, peeled and sliced
# 1 banana, sliced
# vanilla ice cream
# 2 (12 ounce) canscold ginger ale
# 1 lemon
# 1 clove garlic
# 12 teaspoon mixed French mustard or 12 teaspoon German mustard
# 3 tablespoons oil
# salt & freshly ground black pepper
# 1 baby back rib rack
# 1 cup char siu sauce
# 2 tablespoons sesame oil
# 2 -3 minced garlic cloves
# 1 inch piece fresh ginger, peeled and sliced
# 14 cup sake (from ginger jar)
# 60 ml mango juice
# 60 ml almond syrup
# 40 ml rose syrup
# 1 dash of sour lime juice
# 400 ml lemonade
# 2 gallons zinfandel
# 1 cup brandy
# 12 cup Cointreau liqueur
# 2 quarts orange juice
# 2 cups lemon juice
# 1 cup superfine sugar
# 12 -16 ice cubes
# 2 quarts chilled club soda
# 3 oranges, thinly sliced
# 3 lemons, thinly sliced
# 2 -3 bags frozen mustard greens
# bacon grease
# 2 -3 green onions, chopped
# salt
# 1 pone cooked cornbread
# 1 cup semi-sweet chocolate chips
# 1 teaspoon shortening
# edible glitter or colored sprinkles
# wooden toothpick
# wax paper
# 2 teaspoons sugar
# 14 cup orange juice, chilled
# 2 tablespoons cranberry juice, chilled
# 1 cup champagne, chilled
# 1 orange
# 3 cups rice bubbles
# 1 cup desiccated coconut
# 60 g butter, chopped
# 1 cup marshmallows
# 12 cup white chocolate chips
# 3 tomatoes, sliced thick
# 2 teaspoons chopped fresh basil
# 2 teaspoons olive oil
# 2 teaspoons lemon juice
# 12 teaspoon sugar
# 14 teaspoon pepper
# 1 pint dry red wine (700ml)
# 12 sugar cubes
# 6 whole cloves
# 1 pint boiling water (600 ml)
# 5 ounces triple sec (150ml)
# 5 ounces brandy (150ml)
# grated nutmeg
# 8 cups cider
# 10 ounces frozen sliced strawberries
# 1 -2 tablespoon mulling spices (in bag)
# 8 ounces chocolate (we suggest Scharffen Berger)
# 2 cups heavy cream
# 1 -2 ounce kaffir lime leaf
# 6 egg yolks
# 13 cup sugar
# 1 pinch salt
# 2 lime wedges
# sugar, for dipping
# 12 cup fresh raspberry
# 6 tablespoons vodka
# 4 teaspoons sugar
# 1 12 cups ice cubes
# 14 cup chilled champagne
# 3 tablespoons quick-cooking tapioca
# 12 cup granulated sugar
# 12 cup brown sugar, packed
# 34 teaspoon almond extract
# 12 teaspoon grated nutmeg
# 1 dash salt
# 2 12 cups husked cape gooseberries (ground cherries)
# 2 tablespoons butter
# 1 ripe banana, sliced
# 12 cup Thai Kitchen Coconut Milk
# 12 cup ice cube
# 12 cup pineapple juice
# 2 rosemary sprigs, broken into small pieces
# 12 cup balsamic vinegar
# 23 cup extra virgin olive oil
# 3 garlic cloves, bashed so the skins are split
# 1 tablespoon clear honey
# 1 egg
# 1 cup flour
# 34 cup margarine or 34 cup butter, softened
# 12 cup cornmeal
# 12 teaspoon salt
# 14 teaspoon chili powder (can add more if you like)
# 2 cups shredded cheddar cheese (sometimes we use pepper jack cheese)
# 1 (4 ounce) can green chilies
# 2 tablespoons chopped onions (I sometimes us more as we like onions)
# 1 ounce Kahlua
# ...
# 1 12 lbs medium zucchini
# 1 12 lbs medium yellow squash
# 4 cups acorn squash, peeled and cubed
# 12-1 cup margarine, melted
# 12 cup honey
# 1 teaspoon salt
# 2 (15 1/2 ounce) cans black beans
# 12 teaspoon sugar
# 1 teaspoon ground cumin
# 12 teaspoon chili powder
# 12 teaspoon garlic powder
# 6 -8 tablespoons crushed tortilla chips (optional)
# 1 (12 ounce) package chocolate chips
# 1 (12 ounce) package butterscotch chips
# 1 (5 ounce) can chow mein noodles
# 1 (4 ounce) package salted peanuts
# 3 tablespoons Dijon mustard
# 1 tablespoon sugar
# 1 tablespoon vinegar
# salt
# white pepper
# 12 cup vegetable oil
# 12 cup chopped fresh dill
# 1 34 lbs sea bream
# 100 ml lemon juice
# 1 teaspoon salt
# 1 teaspoon sugar
# 3 teaspoons chopped spring onions
# 1 small red chili pepper
# 100 ml olive oil
# 1 cup spinach, firmly packed,washed and chopped
# 1 cup cooked brown rice
# 12 cup frozen corn kernels
# 14 cup salsa
# 4 flour tortillas or 4 corn tortillas
# 1 ounce orange-infused vodka
# 1 ounce absinthe, mata hari
# 1 ounce hiram walker black raspberry liqueur
# 1 ounce champagne
# 15 Triscuit crackers (I use reduced-fat)
# 12 tablespoon olive oil
# 12 tablespoon garlic powder
# 15 slices parmesan cheese
# 1 large head cauliflower, chopped into florets
# 1 lemon, juice of
# 3 garlic cloves, minced
# 2 teaspoons Dijon mustard
# 1 tablespoon olive oil
# 1 teaspoon salt
# 1 teaspoon dried dill
# fresh black pepper, to taste
# 2 tablespoons nutritional yeast
# 1 cup caster sugar
# 300 ml water
# 4 lemons
# 1 egg white
# 1 sprig fresh lavender (garnish)
# 1 lemon wedge (garnish)
# 12 ounce simple syrup
# 34 ounce fresh lemon juice
# 2 ounces scotch
# 4 ounces apple cider
# 12 green pepper, diced
# 12 small onion, diced
# 1 cup cooked black beans (if from a can then drain and rinse first)
# 12 cup canned diced tomato
# 12 cup frozen corn
# 1 tablespoon taco seasoning
# 1 cup cooked brown rice
# hot sauce (optional)
# salt
# 1 12 cups whole wheat flour
# 1 12 teaspoons baking powder
# 34 teaspoon baking soda
# 13 teaspoon salt
# 1 12 teaspoons cinnamon
# 34 teaspoon ground ginger
# 13 teaspoon nutmeg
# 34 cup Egg Beaters egg substitute
# 1 cup sweet potato (mashed)
# 34 cup sugar-free maple syrup
# 2 lbs eggplants
# 2 garlic cloves, sliced
# 3 medium tomatoes, peeled deseeded and chopped
# 1 teaspoon paprika
# 12 teaspoon ground cumin
# 1 tablespoon cilantro, chopped
# 1 12 tablespoons olive oil
# 3 tablespoons lemon juice
# 34 cup acini di pepe pasta
# 3 ounces vanilla instant pudding mix
# 1 (11 ounce) can mandarin oranges, drained
# 1 (20 ounce) can crushed pineapple (with juice)
# 1 (8 ounce) container Cool Whip
# 3 -6 lbs chicken bones (backs, necks, carcasses, and or or wing tips, amount is very forgiving)
# 3 quarts water
# 2 large onions, unpeeled, coarsely chopped
# 4 stalks celery, coarsely chopped
# 3 medium carrots, coarsely chopped
# 4 garlic cloves, crushed
# 3 dried bay leaves
# 8 fresh parsley stems (Italian or curly)
# 6 sprigs fresh thyme
# 2 teaspoons black peppercorns
# 1 tablespoon sea salt (or kosher)
# 1 -2 potato (and or peels will add richness and depth)
# 1 -2 bell pepper
# 1 (16 ounce) can cut green beans, drained
# 1 (16 ounce) can garbanzo beans, drained
# 1 (15 ounce) can pinto beans, drained
# 1 large sweet red pepper, cut in strips
# 1 small purple onion, thinly sliced and seperated into rings
# 12 cup cider vinegar
# 13 cup vegetable oil
# 1 tablespoon sugar
# 1 garlic clove, crushed
# 12 teaspoon crushed red pepper flakes
# 12 teaspoon chili powder
# 14 teaspoon ground cumin
# 14 teaspoon ground coriander
# lettuce leaf
# 2 lbs fresh asparagus
# 14 cup sugar (or sugar substitute if desired)
# 14 cup apple cider vinegar
# 14 cup soy sauce
# 2 tablespoons vegetable oil
# 34 cup pecans, toasted and finely chopped
# fresh ground pepper
# 1 lb lean boneless sirloin, trimmed,and cut into 1/4 inch thick strips (partially frozen steak is easier to cut)
# 2 teaspoons peeled minced ginger
# 14 teaspoon grated orange rind
# 12 cup orange juice
# 2 tablespoons balsamic vinegar
# 2 tablespoons low sodium soy sauce
# 2 teaspoons cornstarch
# 1 teaspoon oil
# 12 lb fresh snow pea pods, ends trimmed and strings removed
# 12 cup celery, sliced on the diagonal
# 12 cup red pepper, sliced into strips
# 1 cup cashew nuts
# 1 cup coconut, shredded
# 13 cup sugar
# 1 tablespoon salt
# 13 cup vanilla-flavored soymilk (or add more for desired thickness)
# 2 teaspoons cocoa powder (optional)
# nutmeg, sprinkle
# cinnamon, sprinkle to taste
# 1 (15 ounce) can chickpeas, rinsed and drained
# 12 cup finely chopped fresh parsley
# 3 tablespoons fresh lemon juice
# 1 tablespoon olive oil
# 1 clove garlic, minced
# 4 cups mixed baby greens
# 12 thinly sliced English cucumber
# 12 medium thinly sliced red onion
# 12 cup Greek yogurt or 12 cup regular yoghurt, drained in cheesecloth till thick
# 14 teaspoon ground cumin
# 1 dash Tabasco sauce
# 4 whole wheat pita bread
# 1 lb sweet potato, peeled and cubed
# 34 teaspoon ginger
# 14 cup honey or 14 cup maple syrup
# 34 teaspoon cinnamon
# 2 teaspoons melted margarine
# 2 tablespoons chopped walnuts or 2 tablespoons pecans
# 34 cup peeled apple, cubed
# 30 ml captain morgan spiced rum
# cream soda (Faygo or A&W)
# crushed ice
# 12 lb panir (Deep fry after making cubes and immerse in water for 5 minutes to make them go soft)
# 2 medium onions
# 2 -3 tomatoes (pureed)
# 2 tablespoons ginger-garlic paste
# 1 green chili
# 1 teaspoon dried fenugreek leaves (kasuri methi-available at the asian stores...)
# 1 tablespoon poppy seed
# 15 whole cashews
# 12-1 teaspoon chili powder
# 12 teaspoon garam masala
# 14 teaspoon turmeric powder
# cilantro
# 1 big brown cardamom pod
# 1 tablespoon oil
# 1 gallon green to pink tomatoes (about 10 lbs)
# 1 gallon cabbage (about 7 lbs)
# 1 gallon onion (about 10 lbs)
# 1 quart green bell pepper (about 3 lbs)
# 4 red bell peppers
# 3 quarts vinegar
# 3 lbs sugar (about 3 3/4 cups)
# 1 tablespoon turmeric
# 1 tablespoon ground allspice
# 1 tablespoon ground cinnamon
# 1 tablespoon celery seed
# jalapeno pepper, can be added
# 1 turkey
# your favorite seasoning
# 2 teaspoons olive oil
# 1 garlic clove, minced
# 2 cups small red potatoes, quartered
# 1 12 tablespoons fresh parsley, chopped
# 14 teaspoon salt
# 1 dash crushed red pepper flakes
# 8 ounces tempeh
# 38 cup nutritional yeast flakes
# 18 cup whole wheat pastry flour
# 14 teaspoon salt
# 14 teaspoon garlic powder
# 14 cup water
# 13 cup soybean oil
# 18 teaspoon horseradish
# 14 tablespoon prepared mustard
# 38 cup sauerkraut
# 1 ounce puerto rican light rum
# 2 -3 ounces ginger ale
# 1 ounce orange juice
# orange slice, to garnish
# 1 small star fruit, to garnish
# 12 lb whole wheat spaghetti
# 3 tablespoons olive oil
# 4 large garlic cloves, peeled and chopped
# 1 12 lbs of ripe tomatoes, coarsely chopped
# 34 cup cooked chickpeas
# 2 tablespoons fresh herbs, chopped
# 2 tablespoons kalamata olives, chopped
# 1 lb fresh strawberries, cut into quarters
# 14 cup sugar or 14 cup sugar substitute
# 14 cup water
# 14 teaspoon vanilla
# 1 good squeeze fresh lemon
# 12 cup white rice
# salt and pepper
# 1 carrot, cut into 1/4-inch cubes
# 14 cup extra virgin olive oil
# 2 teaspoons red wine vinegar
# 12 teaspoon dried oregano
# 1 ear of corn, kernels scraped off
# 1 cup frozen peas
# 2 stalks celery, cut into 1/4-inch cubes
# 2 tablespoons celery leaves, chopped
# 1 small red onion, thinly sliced
# 100 g soya flour
# 600 ml water
# 2 lemons, juice of
# cooking spray
# 1 large tomatoes, chopped
# 12 cup chopped onion
# 1 clove garlic, minced
# 12 teaspoon dried oregano
# 14 teaspoon ground cumin
# 1 cup long grain rice
# 14 ounces vegetable broth
# 13 cup water
# 1 carrot, cooked, diced
# 12 cup frozen peas, thawed
# salt and pepper
# 1 teaspoon matcha green tea powder
# 12 ounce Grand Marnier or 12 ounce favorite brandy or 12 ounce rum
# 2 ounces ketel one citrus-infused vodka or 2 ounces other smooth vodka
# 12 lb green beans, washed
# 12 lemon, juice of, squeezed
# 14 cup extra virgin olive oil
# 14 teaspoon salt
# 1 garlic clove, sliced
# mint leaf, washed
# 1 teaspoon Jello gelatin
# water, as needed
# 12 medium onion, chopped
# 12 small cabbage, chopped
# 1 medium carrot, thinly sliced
# 12 cup water
# 14 cup diced tomato
# 2 tablespoons red wine vinegar
# 1 12 teaspoons sugar
# 14 teaspoon black pepper, freshly ground
# 14 cup peanuts, chopped
# 4 cups simple syrup
# 25 fresh strawberries, sliced
# 1 lb loaf thawed frozen bread dough
# 2 teaspoons cumin seeds (use 1 kind or several) or 2 teaspoons dill seeds (use 1 kind or several) or 2 teaspoons fennel seeds (use 1 kind or several) or 2 teaspoons sesame seeds (use 1 kind or several) or 2 teaspoons poppy seeds (use 1 kind or several)
# 12 teaspoon coarse salt
# 1 (14 1/2 ounce) can diced tomatoes
# 12 cup water
# 3 garlic cloves, minced
# 2 bay leaves
# 12 teaspoon cayenne pepper, to taste
# 1 teaspoon chili powder
# 1 teaspoon garlic powder
# 1 teaspoon italian seasoning
# 1 (15 ounce) can black beans, rinsed and drained
# 1 (15 ounce) can kidney beans, rinsed and drained
# 13 cup creamy peanut butter
# 1 dash salt, to taste
# 1 dash pepper, to taste
# 1 cup cheddar cheese, shredded (optional)
# 2 cups tortilla chips (optional)
# 2 medium potatoes, peeled & cut in half
# 4 medium carrots, peeled and half cooked
# 2 parsnips, peeled, half cooked, cut in half
# 2 medium onions, peeled, cross cut on top, sprinkled with a bit of balsamic vinegar
# 1 head garlic, outer skin removed, sprinkled with olive oil on top
# 6 large mushrooms, cleaned (or any combination of veggies that you want, however root veggies are best, broccoli etc. do not len)
# salt & pepper
# 200 g frozen raspberries, thawed
# 14 cup caster sugar
# 4 peppermint tea bags
# 12 cup spearmint, leaves
# crushed ice, to serve
# 2 teaspoons oil
# 1 cup celery, chopped
# 1 medium onion, chopped
# 1 small bell pepper, chopped (red or green)
# 2 jalapeno peppers, seeded and finely chopped
# 16 ounces no-salt-added tomato sauce
# 15 12 ounces red beans, rinsed
# 15 ounces black beans, rinsed
# 14 12 ounces vegetable broth
# 12 cup long grain rice, uncooked
# 12 teaspoon hot red pepper sauce
# 1 lb tomatoes, seeded & cut into 1-inch squares (2 large or 3 medium)
# 1 lb of fresh tofu, drained & cut into 1-inch squares (extra firm works)
# 1 tablespoon vegetable oil
# 1 tablespoon minced garlic
# 12 cup chopped scallion
# 1 teaspoon salt
# 12 teaspoon sugar
# 1 teaspoon soy sauce
# 14 teaspoon ground coriander
# black pepper
# 13 cup Splenda granular
# 14 cup cocoa
# 3 tablespoons cornstarch
# 18 teaspoon salt
# 2 cups skim milk
# 1 teaspoon vanilla extract
# 1 cup polenta or 1 cup yellow cornmeal
# 3 tablespoons butter or 3 tablespoons margarine
# 1 (14 1/2 ounce) can chicken broth
# 1 34 cups water
# grated parmesan cheese
# salt and pepper
# 4 large apples
# 2 large pears
# 1 teaspoon fresh rosemary, finely chopped
# 2 bay leaves
# 5 tablespoons fresh lemon juice, divided
# 13 cup balsamic vinegar
# 13 cup brown sugar
# 3 tablespoons butter
# 6 ounces pomegranate juice
# 4 ounces skim milk
# 14 cup raspberries
# 12 cup pineapple, chopped
# 4 strawberries, halved
# 1 banana, sliced
# 6 tablespoons butter
# 3 tablespoons toasted sesame oil
# 3 tablespoons vegetable oil
# 1 12 lbs Brussels sprouts, halved
# 12 teaspoon crushed red pepper flakes
# salt and pepper
# 3 tablespoons sesame seeds
# 1 (28 ounce) can plum tomatoes, preferably San Marzano variety
# 2 tablespoons olive oil
# 2 garlic cloves, chopped
# 2 tablespoons pine nuts
# 2 tablespoons golden raisins, plumped in hot water then drained
# 12 cup black olives, pitted and roughly chopped
# 2 tablespoons capers, chopped
# salt, to taste
# fresh ground black pepper, to taste
# 1 cup dry lentils
# 1 large onion, minced
# 2 carrots, diced
# 2 celery ribs, sliced
# 6 large garlic cloves, minced
# 2 cups tomato puree, canned chopped
# 4 ounces spaghetti, broken into 2 inch lengths
# 2 cups spinach, sliced
# 14 cup olive oil
# salt and pepper
# 1 lb asparagus
# 3 tablespoons balsamic vinegar
# 4 tablespoons fresh pineapple juice
# 1 tablespoon olive oil
# 1 tablespoon low sodium soy sauce
# 18 teaspoon black pepper
# 34 cup diced can tomatoes, fresh
# 18 cup finely dice red onion
# 1 garlic clove, minced
# 18 teaspoon salt
# fresh ground black pepper
# 2 tablespoons balsamic vinegar
# 4 -8 fresh basil leaves, garnish
# 2 ounces Sprite
# 2 ounces blue curacao
# 1 ounce club soda
# 2 ounces Blueberry Schnapps
# 1 lb pasta
# 1 hot pepper, crushed
# 12 cup olive oil
# 4 garlic cloves, minced
# 12 cup breadcrumbs (optional)
# 3 aspirin, tablets
# water (a few drops)
# 12 cup orrisroot chips
# 15 drops cinnamon oil
# 10 drops clove oil
# 5 drops orange oil
# 1 cup broken cinnamon stick
# 1 cup whole allspice
# 1 cup dried orange peel
# 1 cup bay leaf
# 1 cup coriander
# 1 cup mint
# 12 cup whole cloves
# 12 cup star anise
# 12 cup pine needles
# 12 cup rosemary
# 1 (750 ml) bottle red wine
# 4 whole cloves
# 1 cinnamon stick
# 12 to 1 lemon, rind of
# 14 cup sugar, to taste
# 4 tablespoons honey, organic
# 12 teaspoon lavender
# 1 garlic clove, minced
# butter, and olive oil for sauteing
# 1 cup white pearl onion, peeled
# 1 cup fava beans, peeled and blanched
# 1 cup new potato, blanched
# 13 cup red wine (shiraz, zinfandel or cabernet)
# 12 cup lamb stock (or beef)
# 3 tablespoons unsalted butter, chilled
# 1 pinch nutmeg, freshly grated
# 2 teaspoons thyme, fresh
# 18 bone racks of lamb (domestic spring)
# salt and pepper
# 2 23 cups sweetened flaked coconut
# 23 cup sugar
# 13 cup flour
# 14 teaspoon salt
# 4 egg whites
# 12 teaspoon almond extract
# 2 ounces semisweet chocolate
# 12 teaspoon shortening
# 1 (16 ounce) carton strawberries
# 1 (12 ounce) bag white chocolate
# 1 (12 ounce) bag chocolate chips
# 1 ounce red decorating gel
# 1 (10 ounce) package romaine lettuce, salad
# 1 cup refrigerated mango, chopped
# 12 cup sliced red onion
# 13 cup fat free balsamic vinaigrette
# 1 cup unsweetened vanilla Almond Breeze, divided (I used BlueDiamond Unsweetened Original Almond Breeze but listed the Vanilla for nutritional accurac)
# 14 cup gluten-free quick oats (Bob's Red Mill)
# 20 -25 whole almonds, chopped
# 20 -25 dried blueberries (or fresh depending on the season)
# 12 banana, mashed (ripe, small brown spots starting to appear)
# 3 tablespoons lemon juice
# 3 tablespoons olive oil
# 3 tablespoons minced fresh cilantro or 3 tablespoons parsley
# sea salt & freshly ground black pepper, to taste
# 1 12 cups water
# 1 cup frozen corn (can use fresh)
# 12 cup quinoa, rinsed thoroughly
# 12 teaspoon cumin seed, toasted
# 1 cup cooked black beans, rinsed and drained
# 1 medium tomatoes, diced
# 3 tablespoons minced red onions
# 2 12 cups rolled oats
# 13 cup natural-style peanut butter
# 3 tablespoons honey
# 12 cup dark chocolate chips
# 1 12 ounces vodka
# 1 12 ounces Tia Maria
# chocolate milk
# ice
# 30 ml vodka
# 60 ml Midori melon liqueur
# 150 ml sour mix
# 1 slice orange
# 2 teaspoons unsalted butter
# 14 cup white sugar
# 1 pint blueberries
# 1 (15 ounce) can pineapple chunks in juice
# habanero pepper, finrly diced
# 1 cup sugar
# 3 tablespoons cinnamon
# tortilla chips
# 1 quart ice cream (optional)
# hamburger
# milk
# salt and pepper
# cream soup, vegetables, meat, etc. as available
# 1 ounce bacardi white rum
# 12 ounce Cointreau liqueur
# 1 dash lemon juice
# 2 cups shortbread cookies, crushed
# 1 14 cups sifted confectioners' sugar
# 1 cup walnuts, finely chopped
# 2 tablespoons unsweetened cocoa powder
# 1 12 teaspoons instant coffee crystals or 1 12 teaspoons instant espresso powder
# 14 teaspoon ground cinnamon
# 4 -5 tablespoons brewed espresso or 4 -5 tablespoons strong coffee or 4 -5 tablespoons water
# 12 cup sifted confectioners' sugar
# sifted confectioners' sugar (optional)
# 1 (16 ounce) box fat free angel food cake mix
# 1 (14 ounce) can crushed pineapple in juice, don't drain juice
# 1 (10 ounce) can mandarin oranges in juice, drain juice
# 1 orange, zest of
# 3 ounces orange juice
# 1 ounce white tequila
# 1 ounce triple sec
# 1 ounce cranberry juice
# orange wedge, for garnish
# coarse sugar, for garnish
# 1 ounce Godiva white chocolate liqueur
# 12 ounce Godiva original chocolate liqueur
# 12 ounce ciroc grape vodka or 12 ounce other grape vodka
# 3 tablespoons rolled oats (bulk section of supermarket)
# 6 tablespoons water
# 6 strawberries
# 1 tablespoon lemon juice
# 1 tablespoon dried cranberries (I used Pomegranate flavored)
# 1 tablespoon pecans, chopped
# 1 tablespoon clear honey
# 1 tablespoon lavender flowers
# 10 tablespoons caster sugar
# 30 ml Midori melon liqueur
# 15 ml peach vodka
# 15 ml rubis strawberry liqueur
# pineapple juice
# cranberry juice
# ice
# 1 fresh strawberries
# milk (says "ready-made")
# chocolate syrup
# 12 lb unsalted butter
# 12 cup sugar
# 1 egg yolk
# 2 tablespoons maple syrup
# 12 teaspoon vanilla
# 1 34 cups all-purpose flour, sifted, plus
# 2 tablespoons all-purpose flour, sifted
# 1 14 cups pecans, pieces

# %%
df.head()
# Out:
#                                           ingredients  \
# 0   8 boneless skinless chicken breasts 1 (6 ounce...
# 3   34 cup butter 14 ounces sweetened condensed mi...
# 4   4 ounces cream cheese 12 cup purchased seafood...
# 7   1 (9 ounce) boxjiffy golden yellow cake mix 1 ...
# 10  1 (15 ounce) can refried beans 1 packet taco s...
#
#                                                   url  \
# 0   http://www.food.com/recipe/tangy-citrus-chicke...
# 3   http://www.food.com/recipe/chocolate-peanut-bu...
# 4   http://www.food.com/recipe/cream-cheese-seafoo...
# 7   http://www.food.com/recipe/christmas-santa-cup...
# 10  http://www.food.com/recipe/canadian-mexican-di...
#
#                                          title          id  \
# 0                         Tangy Citrus Chicken  02010fa63e
# 3   Chocolate Peanut Butter Butterscotch Fudge  0161a01cfd
# 4                Cream Cheese & Seafood Spread  284f827a2a
# 7                     Christmas Santa Cupcakes  016933d1f6
# 10                        Canadian Mexican Dip  196f17b7e2
#
#                                          instructions  \
# 0   [{'text': 'Preheat oven to 350F.'}, {'text': '...
# 3   [{'text': 'Melt butter in a heavy saucepan ove...
# 4   [{'text': 'Spread softened cream cheese into t...
# 7   [{'text': 'Preheat oven to 350.'}, {'text': 'M...
# 10  [{'text': 'Mix the re-fried beans with half th...
#
#                                             nutrition  calories  fatContent  \
# 0   {'calories': '245.3', 'fatContent': '1.6', 'sa...     245.3         1.6
# 3   {'calories': '225.2', 'fatContent': '15.4', 's...     225.2        15.4
# 4   {'calories': '94.8', 'fatContent': '7', 'satur...      94.8         7.0
# 7   {'calories': '198', 'fatContent': '5.7', 'satu...     198.0         5.7
# 10  {'calories': '343.3', 'fatContent': '23.7', 's...     343.3        23.7
#
#     saturatedFatContent  cholesterolContent  sodiumContent  \
# 0                   0.4                68.4           78.7
# 3                   6.1                10.8           57.5
# 4                   4.2                26.4          294.0
# 7                   1.0                31.9          292.4
# 10                  9.7                34.1          705.1
#
#     carbohydrateContent  fiberContent  sugarContent  proteinContent
# 0                  30.6           0.2          29.8            27.5
# 3                  20.0           1.4          16.4             4.0
# 4                   3.4           0.0           0.0             4.8
# 7                  33.4           0.5          18.6             2.9
# 10                 22.4           8.7           2.7            13.5

# %%
df['ingredients'][0]
# Out:
# '8 boneless skinless chicken breasts 1 (6 ounce) can frozen lemonade concentrate, thawed 12 cup honey 1 teaspoon rubbed sage 12 teaspoon ground mustard 12 teaspoon dried thyme 12 teaspoon lemon juice'

# %%
df.dtypes
# Out:
# ingredients             object
# url                     object
# title                   object
# id                      object
# instructions            object
# nutrition               object
# calories               float64
# fatContent             float64
# saturatedFatContent    float64
# cholesterolContent     float64
# sodiumContent          float64
# carbohydrateContent    float64
# fiberContent           float64
# sugarContent           float64
# proteinContent         float64
# dtype: object

# %%
import nltk
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\ankur\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
#Stopwords removal
from nltk.corpus import stopwords
stop = stopwords.words('english')

# %%
df['ingredients'].apply(lambda x: [item for item in x if item not in stop])
df['ingredients']
# Out:
# 0      8 boneless skinless chicken breasts 1 (6 ounce...
# 3      34 cup butter 14 ounces sweetened condensed mi...
# 4      4 ounces cream cheese 12 cup purchased seafood...
# 7      1 (9 ounce) boxjiffy golden yellow cake mix 1 ...
# 10     1 (15 ounce) can refried beans 1 packet taco s...
#                              ...
# 756    3 tablespoons rolled oats (bulk section of sup...
# 757    1 tablespoon lavender flowers 10 tablespoons c...
# 758    30 ml Midori melon liqueur 15 ml peach vodka 1...
# 759             milk (says "ready-made") chocolate syrup
# 760    12 lb unsalted butter 12 cup sugar 1 egg yolk ...
# Name: ingredients, Length: 621, dtype: object

# %%
import re

# %%
df['ingredients'] = df['ingredients'].str.replace('\d+', '')

# %%
df['ingredients'] = df.ingredients.apply(lambda x: str(x.lower()))

# %%
df.ingredients
# Out:
# 0       boneless skinless chicken breasts  ( ounce) c...
# 3       cup butter  ounces sweetened condensed milk  ...
# 4       ounces cream cheese  cup purchased seafood sa...
# 7       ( ounce) boxjiffy golden yellow cake mix  tea...
# 10      ( ounce) can refried beans  packet taco seaso...
#                              ...
# 756     tablespoons rolled oats (bulk section of supe...
# 757     tablespoon lavender flowers  tablespoons cast...
# 758     ml midori melon liqueur  ml peach vodka  ml r...
# 759             milk (says "ready-made") chocolate syrup
# 760     lb unsalted butter  cup sugar  egg yolk  tabl...
# Name: ingredients, Length: 621, dtype: object

# %%
df['ingredients'] = df['ingredients'].apply(lambda x: " ".join(x.split()))

# %%
df['ingredients']  = df['ingredients'] .apply(lambda x: re.sub('[^A-Z a-z 0-9-]+', '', x))   #removing special char

# %%
df['ingredients']
# Out:
# 0      boneless skinless chicken breasts  ounce can f...
# 3      cup butter ounces sweetened condensed milk tab...
# 4      ounces cream cheese cup purchased seafood sauc...
# 7       ounce boxjiffy golden yellow cake mix teaspoo...
# 10      ounce can refried beans packet taco seasoning...
#                              ...
# 756    tablespoons rolled oats bulk section of superm...
# 757    tablespoon lavender flowers tablespoons caster...
# 758    ml midori melon liqueur ml peach vodka ml rubi...
# 759                 milk says ready-made chocolate syrup
# 760    lb unsalted butter cup sugar egg yolk tablespo...
# Name: ingredients, Length: 621, dtype: object

# %%
# Lemmatization
import nltk
from nltk.stem import WordNetLemmatizer

# %%
lemmatizer = WordNetLemmatizer()
for i in df.ingredients.index:
    words = nltk.word_tokenize(df.ingredients[i])
    words = [lemmatizer.lemmatize(word) for word in words if word not in set(stopwords.words('english'))]
    df.ingredients[i] = ' '.join(words)
# Out:
# <ipython-input-33-ad099884648c>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.ingredients[i] = ' '.join(words)

# %%
df['unique_ingredients'] = ""

# %%
#creating set for each 'ingredients'

for i in df.ingredients.index:
    unique = set()
    for j in df.ingredients[i].split(" "):
        unique.add(j)
    df['unique_ingredients'][i] = unique
# Out:
# <ipython-input-35-4e3a5e229657>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['unique_ingredients'][i] = unique

# %%
df['unique_ingredients'] = df['unique_ingredients'].apply(lambda x: list(x)) # set to list

# %%
df.unique_ingredients = df.ix[:,15]
# Out:
# <ipython-input-37-bd4297c115e3>:1: FutureWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#ix-indexer-is-deprecated
#   df.unique_ingredients = df.ix[:,15]

# %%
df.unique_ingredients
# Out:
# 0      [rubbed, ounce, thyme, breast, boneless, cup, ...
# 3      [sweetened, vanilla, ounce, condensed, milk, t...
# 4      [cup, sauce, serve, assorted, ounce, imitation...
# 7      [cup, coloring, cake, boxjiffy, red, teaspoon,...
# 10     [ounce, corn, grated, bean, cheese, cup, sprin...
#                              ...
# 756    [section, tablespoon, clear, cranberry, flavor...
# 757        [caster, sugar, lavender, tablespoon, flower]
# 758    [vodka, midori, pineapple, strawberry, ice, ml...
# 759            [syrup, ready-made, milk, chocolate, say]
# 760    [cup, butter, sugar, syrup, teaspoon, all-purp...
# Name: unique_ingredients, Length: 621, dtype: object

# %%
df
# Out:
#                                            ingredients  \
# 0    boneless skinless chicken breast ounce frozen ...
# 3    cup butter ounce sweetened condensed milk tabl...
# 4    ounce cream cheese cup purchased seafood sauce...
# 7    ounce boxjiffy golden yellow cake mix teaspoon...
# 10   ounce refried bean packet taco seasoning packe...
# ..                                                 ...
# 756  tablespoon rolled oat bulk section supermarket...
# 757  tablespoon lavender flower tablespoon caster s...
# 758  ml midori melon liqueur ml peach vodka ml rubi...
# 759                milk say ready-made chocolate syrup
# 760  lb unsalted butter cup sugar egg yolk tablespo...
#
#                                                    url  \
# 0    http://www.food.com/recipe/tangy-citrus-chicke...
# 3    http://www.food.com/recipe/chocolate-peanut-bu...
# 4    http://www.food.com/recipe/cream-cheese-seafoo...
# 7    http://www.food.com/recipe/christmas-santa-cup...
# 10   http://www.food.com/recipe/canadian-mexican-di...
# ..                                                 ...
# 756  http://www.food.com/recipe/easy-overnight-mues...
# 757   http://www.food.com/recipe/lavender-sugar-190508
# 758  http://www.food.com/recipe/sex-on-the-bridge-3...
# 759  http://www.food.com/recipe/hot-chocolate-made-...
# 760  http://www.food.com/recipe/maple-pecan-cookies...
#
#                                                  title          id  \
# 0                                 Tangy Citrus Chicken  02010fa63e
# 3           Chocolate Peanut Butter Butterscotch Fudge  0161a01cfd
# 4                        Cream Cheese & Seafood Spread  284f827a2a
# 7                             Christmas Santa Cupcakes  016933d1f6
# 10                                Canadian Mexican Dip  196f17b7e2
# ..                                                 ...         ...
# 756  Easy, Overnight Muesli - Strawberry Version (S...  1b324d3668
# 757                                     Lavender Sugar  02585c8c11
# 758                                  Sex on the Bridge  0091ff9f87
# 759                       Hot Chocolate Made With Milk  0219edad24
# 760                                Maple Pecan Cookies  1af1d8ad42
#
#                                           instructions  \
# 0    [{'text': 'Preheat oven to 350F.'}, {'text': '...
# 3    [{'text': 'Melt butter in a heavy saucepan ove...
# 4    [{'text': 'Spread softened cream cheese into t...
# 7    [{'text': 'Preheat oven to 350.'}, {'text': 'M...
# 10   [{'text': 'Mix the re-fried beans with half th...
# ..                                                 ...
# 756  [{'text': 'Before you go to bed, put the oats ...
# 757  [{'text': 'mix together and keep in a tightly ...
# 758  [{'text': 'Mix alcohol in a highball glass and...
# 759  [{'text': 'First, make your old favorite.'}, {...
# 760  [{'text': 'Preheat oven to 325F.'}, {'text': '...
#
#                                              nutrition  calories  fatContent  \
# 0    {'calories': '245.3', 'fatContent': '1.6', 'sa...     245.3         1.6
# 3    {'calories': '225.2', 'fatContent': '15.4', 's...     225.2        15.4
# 4    {'calories': '94.8', 'fatContent': '7', 'satur...      94.8         7.0
# 7    {'calories': '198', 'fatContent': '5.7', 'satu...     198.0         5.7
# 10   {'calories': '343.3', 'fatContent': '23.7', 's...     343.3        23.7
# ..                                                 ...       ...         ...
# 756  {'calories': '62.2', 'fatContent': '2.9', 'sat...      62.2         2.9
# 757  {'calories': '48.8', 'fatContent': '0', 'satur...      48.8         0.0
# 758  {'calories': '36.6', 'fatContent': '0', 'satur...      36.6         0.0
# 759  {'calories': '0', 'fatContent': '0', 'saturate...       0.0         0.0
# 760  {'calories': '55.1', 'fatContent': '4', 'satur...      55.1         4.0
#
#      saturatedFatContent  cholesterolContent  sodiumContent  \
# 0                    0.4                68.4           78.7
# 3                    6.1                10.8           57.5
# 4                    4.2                26.4          294.0
# 7                    1.0                31.9          292.4
# 10                   9.7                34.1          705.1
# ..                   ...                 ...            ...
# 756                  0.3                 0.0            1.3
# 757                  0.0                 0.0            0.0
# 758                  0.0                 0.0            0.3
# 759                  0.0                 0.0            0.0
# 760                  1.8                 9.4            0.6
#
#      carbohydrateContent  fiberContent  sugarContent  proteinContent  \
# 0                   30.6           0.2          29.8            27.5
# 3                   20.0           1.4          16.4             4.0
# 4                    3.4           0.0           0.0             4.8
# 7                   33.4           0.5          18.6             2.9
# 10                  22.4           8.7           2.7            13.5
# ..                   ...           ...           ...             ...
# 756                  9.2           1.2           5.5             1.0
# 757                 12.6           0.0          12.6             0.0
# 758                  0.9           0.2           0.6             0.1
# 759                  0.0           0.0           0.0             0.0
# 760                  4.5           0.3           1.8             0.6
#
#                                     unique_ingredients
# 0    [rubbed, ounce, thyme, breast, boneless, cup, ...
# 3    [sweetened, vanilla, ounce, condensed, milk, t...
# 4    [cup, sauce, serve, assorted, ounce, imitation...
# 7    [cup, coloring, cake, boxjiffy, red, teaspoon,...
# 10   [ounce, corn, grated, bean, cheese, cup, sprin...
# ..                                                 ...
# 756  [section, tablespoon, clear, cranberry, flavor...
# 757      [caster, sugar, lavender, tablespoon, flower]
# 758  [vodka, midori, pineapple, strawberry, ice, ml...
# 759          [syrup, ready-made, milk, chocolate, say]
# 760  [cup, butter, sugar, syrup, teaspoon, all-purp...
#
# [621 rows x 16 columns]

# %%
df.to_csv(r"C:\Users\ankur\OneDrive\Desktop\Internship\unique_ingre.csv", index= False)

# %% [markdown]
# # Allergy

# %%
allergy = pd.read_csv(r"C:\Users\ankur\OneDrive\Desktop\Internship\allergy_lower.csv")

# %%
allergy
# Out:
#              Class                    Type                 Group        Food  \
# 0     plant origin            nut and seed              oil seed      almond
# 1     plant origin                   fruit            pome fruit       apple
# 2     plant origin                   fruit           stone fruit     apricot
# 3     plant origin               vegetable   composite vegetable   artichoke
# 4     plant origin               vegetable  liliaceous vegetable   asparagus
# ..             ...                     ...                   ...         ...
# 157   plant origin  cereal grain and pulse          cereal grain       wheat
# 158  animal origin                   dairy                 dairy        whey
# 159   plant origin  cereal grain and pulse                 pulse  white bean
# 160   plant origin               vegetable                potato         yam
# 161  animal origin                   dairy                 dairy     yogurt
#
#                                 Allergy
# 0                           nut allergy
# 1                 oral allergy syndrome
# 2                   stone fruit allergy
# 3                       insulin allergy
# 4                        allium allergy
# ..                                  ...
# 157                      gluten allergy
# 158  milk allergy / lactose intolerance
# 159                      legume allergy
# 160                      potato allergy
# 161  milk allergy / lactose intolerance
#
# [162 rows x 5 columns]

# %%
allergy.Class.value_counts()
# Out:
# plant origin      124
# animal origin      37
# mineral waters      1
# Name: Class, dtype: int64

# %% [markdown]
# # for animal class allergies

# %%
animal_origin = allergy[allergy.Class == 'animal origin']

# %%
animal_origin.head()
# Out:
#             Class                Type  Group        Food  \
# 13  animal origin      aquatic animal   fish      bonito
# 19  animal origin               dairy  dairy      butter
# 21  animal origin               dairy  dairy  buttermilk
# 25  animal origin               dairy  dairy      casein
# 26  animal origin  terrestrial mammal  offal      cattle
#
#                                Allergy
# 13                   histamine allergy
# 19  milk allergy / lactose intolerance
# 21  milk allergy / lactose intolerance
# 25  milk allergy / lactose intolerance
# 26                  alpha-gal syndrome

# %%
animal_origin.Type.unique()
# Out:
# array(['aquatic animal', 'dairy', 'terrestrial mammal', 'poultry',
#        'bee product'], dtype=object)

# %%
animal_origin[animal_origin.Type == 'aquatic animal'].Food.unique()
# Out:
# array(['bonito', 'crustaceans', 'eel', 'globfish', 'horse mackerel',
#        'mackerel', 'percifomes', 'salmon', 'sea bass', 'sea bream',
#        'shelled mollusc', 'tetraodontiformes', 'trout', 'tuna'],
#       dtype=object)

# %%
animal_origin[animal_origin.Type == 'dairy'].Food.unique()
# Out:
# array(['butter', 'buttermilk', 'casein', 'cheese', 'cream', 'custard',
#        'ice cream', 'milk', 'sour cream', 'whey', 'yogurt '], dtype=object)

# %%
animal_origin[animal_origin.Type == 'terrestrial mammal'].Food.unique()
# Out:
# array(['cattle', 'deer', 'goat', 'horse', 'pig', 'sheep'], dtype=object)

# %%
animal_origin[animal_origin.Type == 'poultry'].Food.unique()
# Out:
# array(['chicken', 'duck', 'eggs', 'turkey'], dtype=object)

# %%
animal_origin[animal_origin.Type == 'bee product'].Food.unique()
# Out:
# array(['honey', 'royal jelly'], dtype=object)

# %% [markdown]
# # for plant class allergies

# %%
plant_origin = allergy[allergy.Class == 'plant origin']

# %%
plant_origin.head()
# Out:
#           Class          Type                 Group       Food  \
# 0  plant origin  nut and seed              oil seed     almond
# 1  plant origin         fruit            pome fruit      apple
# 2  plant origin         fruit           stone fruit    apricot
# 3  plant origin     vegetable   composite vegetable  artichoke
# 4  plant origin     vegetable  liliaceous vegetable  asparagus
#
#                  Allergy
# 0            nut allergy
# 1  oral allergy syndrome
# 2    stone fruit allergy
# 3        insulin allergy
# 4         allium allergy

# %%
plant_origin.Type.unique()
# Out:
# array(['nut and seed', 'fruit', 'vegetable', 'cereal grain and pulse',
#        'hop', 'spice and herb', 'tea'], dtype=object)

# %%
plant_origin[plant_origin.Type == 'nut and seed'].Food.unique()
# Out:
# array(['almond', 'chestnut', 'coffee bean', 'cotton seed', 'ginkgo nut',
#        'pecan', 'rapeseed', 'safflower seed', 'sesame seed',
#        'sunflower seed', 'walnut'], dtype=object)

# %%
plant_origin[plant_origin.Type == 'fruit'].Food.unique()
# Out:
# array(['apple', 'apricot', 'avocado', 'banana', 'blackberry', 'blueberry',
#        'cherry', 'cranberry', 'date', 'grape', 'grapefruit', 'guava',
#        'huckleberry', 'japanese pear', 'japanese plum', 'kiwi', 'lemon',
#        'lime', 'loquat', 'mango', 'mume plum', 'nectarine', 'orange',
#        'orange pulp', 'papaya', 'passion fruit', 'peach', 'pear',
#        'pineapple', 'prune', 'quince', 'raspberry', 'strawberry'],
#       dtype=object)

# %%
plant_origin[plant_origin.Type == 'vegetable'].Food.unique()
# Out:
# array(['artichoke', 'asparagus', 'bamboo shoot', 'broccoli',
#        'brussels sprouts', 'burdock', 'button mushroom', 'cabbage',
#        'carrot', 'cauliflower', 'celery', 'chicory', 'chinese cabbage',
#        'egg plant', 'endive', 'fructose', 'garlic', 'ginger', 'glucose',
#        'green soybean', 'horseradish', 'kale', 'kidney bean', 'konjac',
#        'kyona', 'lactose', 'leek', 'lettuce ', 'mitsuba',
#        'mustard spinach', 'nira', 'okra', 'onion', 'parsley', 'parsnip',
#        'peas', 'potato', 'qing-geng-cai', 'radish root', 'salsify',
#        'shallot', 'shiitake  mushroom', 'shungiku', 'spinach', 'sugar',
#        'sugar beet', 'sugarcane', 'sweet pepper', 'sweet potato', 'taro',
#        'tomato', 'turnip root', 'welsh', 'yam'], dtype=object)

# %%
plant_origin[plant_origin.Type == 'cereal grain and pulse'].Food.unique()
# Out:
# array(['barley', 'bean', 'black-eyed bean', 'broad bean', 'buckwheat',
#        'butter bean', 'corn', 'lentil', 'lima bean', 'peanut', 'peas',
#        'pegia', 'popcorn', 'rice', 'rye', 'soybean', 'sultani',
#        'sultapya', 'sweet corn', 'wheat', 'white bean'], dtype=object)

# %%
plant_origin[plant_origin.Type == 'hop'].Food.unique()
# Out:
# array(['hop'], dtype=object)

# %%
plant_origin[plant_origin.Type == 'spice and herb'].Food.unique()
# Out:
# array(['peppermint', 'sansho', 'spearmint'], dtype=object)

# %%
plant_origin[plant_origin.Type == 'tea'].Food.unique()
# Out:
# array(['tea'], dtype=object)

# %%
animal_list = []
plant_list = []
both_list = []
user_input = []
Class = input("class of allergy [plant/animal/both]:")
if Class == 'animal':
    
    print("Enter in how may u have allergy from [aquatic animal/dairy/terrestrial mammal/poultry/bee product] --> ")
    number = int(input())
    for i in range(number):
        inp = input("Choose from [aquatic animal/dairy/terrestrial mammal/poultry/bee product]")
        user_input.append(inp)
    
    
    for i in range(len(user_input)):
        
        if user_input[i] == 'aquatic animal':
            print("Enter in how many u have allergy from [bonito/crustaceans/eel/globfish/horse mackerel/mackerel/percifomes/salmon/sea bass/sea bream/shelled mollusc/tetraodontiformes/trout/tuna] ---> ")
            aqua = int(input())
            for i in range(aqua):
                aquatic = input("bonito/crustaceans/eel/globfish/horse mackerel/mackerel/percifomes/salmon/sea bass/sea bream/shelled mollusc/tetraodontiformes/trout/tuna")
                animal_list.append(aquatic)
        elif user_input[i] == 'dairy':
            print("From [butter/buttermilk/casein/cheese/cream/custard/ice cream/milk/sour cream/whey/yogurt] enter in how many u have allergy")
            aqua = int(input())
            for i in range(aqua):
                dairy = input("butter/buttermilk/casein/cheese/cream/custard/ice cream/milk/sour cream/whey/yogurt ")
                animal_list.append(dairy)
        elif user_input[i] == 'terrestrial mammal':
            print("From [cattle/deer/goat/horse/pig/sheep] enter in how many u have allergy")
            aqua = int(input())
            for i in range(aqua):
                terrestrial = input("cattle/deer/goat/horse/pig/sheep")
                animal_list.append(terrestrial)
        elif user_input[i] == 'poultry':
            print("From [chicken/duck/eggs/turkey] enter in how many u have allergy")
            aqua = int(input())
            for i in range(aqua):
                poultry = input("chicken/duck/eggs/turkey")
                animal_list.append(poultry)
        elif user_input[i] == 'bee product':
            print("From [chicken/duck/eggs/turkey] enter in how many u have allergy")
            aqua = int(input())
            for i in range(aqua):
                bee = input("honey/royal jelly")
                animal_list.append(bee)
                
        

elif Class == 'plant':
    
    print("from [nut and seed/fruit/vegetable/cereal grain and pulse/spice and herb/tea] enter in how may u have allergy")
    number = int(input())
    for i in range(number):
        inp = input("[nut and seed/fruit/vegetable/cereal grain and pulse/spice and herb/tea]")
        user_input.append(inp)
    
    for i in range(len(user_input)):
        if user_input[i] == 'nut and seed':
            print("From [almond/chestnut/coffee bean/sesame seed/walnut] enter in how many u have allergy")
            aqua = int(input())
            for i in range(aqua):
                nut = input("almond/chestnut/coffee bean/sesame seed/walnut")
                plant_list.append(nut)
        elif user_input[i] == 'fruit':
            print("From [apple/apricot/avocado/banana/blackberry/blueberry/cherry/cranberry/date/grape/guava/kiwi/lemon/lime/mango/orange/orange pulp/papaya/peach/pear/pineapple/raspberry/strawberry] enter in how many u have allergy")
            aqua = int(input())
            for i in range(aqua):
                fruit = input("apple/apricot/avocado/banana/blackberry/blueberry/cherry/cranberry/date/grape/guava/kiwi/lemon/lime/mango/orange/orange pulp/papaya/peach/pear/pineapple/raspberry/strawberry")
                plant_list.append(fruit)
        elif user_input[i] == 'vegetable':
            print("From [artichoke/asparagus/broccoli/brussels sprouts/cabbage/carrot/cauliflower/celery/chicory/chinese cabbage/egg plant/fructose/garlic/ginger/glucose/green soybean/horseradish/kale/kidney bean/lactose/lettuce/mustard spinach/okra/onion/parsley/peas/potato/radish root/shallot/shiitake  mushroom/spinach/sugar/sugar beet/sugarcane/sweet pepper/sweet potato/tomato/turnip root/yam] enter in how many u have allergy")
            aqua = int(input())
            for i in range(aqua):
                vegetable = input("artichoke/asparagus/broccoli/brussels sprouts/cabbage/carrot/cauliflower/celery/chicory/chinese cabbage/egg plant/fructose/garlic/ginger/glucose/green soybean/horseradish/kale/kidney bean/lactose/lettuce/mustard spinach/okra/onion/parsley/peas/potato/radish root/shallot/shiitake  mushroom/spinach/sugar/sugar beet/sugarcane/sweet pepper/sweet potato/tomato/turnip root/yam")
                plant_list.append(vegetable)
        elif user_input[i] == 'cereal grain and pulse':
            print("From [barley/bean/black-eyed bean/broad bean/buckwheat/butter bean/corn/lentil/lima bean/peanut/peas/popcorn/rice/rye/soybean/sultani/sweet corn/wheat/white bean] enter in how many u have allergy")
            aqua = int(input())
            for i in range(aqua):
                cereal = input("barley/bean/black-eyed bean/broad bean/buckwheat/butter bean/corn/lentil/lima bean/peanut/peas/popcorn/rice/rye/soybean/sultani/sweet corn/wheat/white bean")
                plant_list.append(cereal)
        elif user_input[i] == 'spice and herb':
            print("From [peppermint/sansho/spearmint] enter in how many u have allergy")
            aqua = int(input())
            for i in range(aqua):
                spice = input("peppermint/sansho/spearmint")
                plant_list.append(spice)
        elif user_input[i] == 'tea':
            tea = input("tea")
            plant_list.append(tea)

        
else:
    
#animal

    print("from [aquatic animal/dairy/terrestrial mammal/poultry/bee product] enter in how many u have allergy")
    number1 = int(input())
    for i in range(number1):
        inp = input("[aquatic animal/dairy/terrestrial mammal/poultry/bee product]")
        user_input.append(inp)
    
    
 
    for i in range(len(user_input)):
        
        if user_input[i] == 'aquatic animal':
            print("From [bonito/crustaceans/eel/globfish/horse mackerel/mackerel/percifomes/salmon/sea bass/sea bream/shelled mollusc/tetraodontiformes/trout/tuna] enter in how many u have allergy")
            aqua = int(input())
            for i in range(aqua):
                aquatic = input("bonito/crustaceans/eel/globfish/horse mackerel/mackerel/percifomes/salmon/sea bass/sea bream/shelled mollusc/tetraodontiformes/trout/tuna")
                both_list.append(aquatic)
        elif user_input[i] == 'dairy':
            print("From [butter/buttermilk/casein/cheese/cream/custard/ice cream/milk/sour cream/whey/yogurt] enter in how many u have allergy")
            aqua = int(input())
            for i in range(aqua):
                dairy = input("butter/buttermilk/casein/cheese/cream/custard/ice cream/milk/sour cream/whey/yogurt ")
                both_list.append(dairy)
        elif user_input[i] == 'terrestrial mammal':
            print("From [cattle/deer/goat/horse/pig/sheep] enter in how many u have allergy")
            aqua = int(input())
            for i in range(aqua):
                terrestrial = input("cattle/deer/goat/horse/pig/sheep")
                both_list.append(terrestrial)
        elif user_input[i] == 'poultry':
            print("From [chicken/duck/eggs/turkey] enter in how many u have allergy")
            aqua = int(input())
            for i in range(aqua):
                poultry = input("chicken/duck/eggs/turkey")
                both_list.append(poultry)
        elif user_input[i] == 'bee product':
            print("From [honey/royal jelly] enter in how many u havve allergy")
            aqua = int(input())
            for i in range(aqua):
                bee = input("honey/royal jelly")
                both_list.append(bee)
                
        

            
#plant            
        
    
    print("from [nut and seed/fruit/vegetable/cereal grain and pulse/spice and herb/tea] enter in how may u have allergy")
    number2 = int(input())
    for i in range(number2):
        inp = input("[nut and seed/fruit/vegetable/cereal grain and pulse/spice and herb/tea]")
        user_input.append(inp)
    
    
    for i in range(len(user_input)):
        if user_input[i] == 'nut and seed':
            print("From [almond/chestnut/coffee bean/sesame seed/walnut] enter in how many u have allergy")
            aqua = int(input())
            for i in range(aqua):
                nut = input("almond/chestnut/coffee bean/sesame seed/walnut")
                both_list.append(nut)
        elif user_input[i] == 'fruit':
            print("From [apple/apricot/avocado/banana/blackberry/blueberry/cherry/cranberry/date/grape/guava/kiwi/lemon/lime/mango/orange/orange pulp/papaya/peach/pear/pineapple/raspberry/strawberry] enter in how many u have allergy")
            aqua = int(input())
            for i in range(aqua):
                fruit = input("apple/apricot/avocado/banana/blackberry/blueberry/cherry/cranberry/date/grape/guava/kiwi/lemon/lime/mango/orange/orange pulp/papaya/peach/pear/pineapple/raspberry/strawberry")
                both_list.append(fruit)
        elif user_input[i] == 'vegetable':
            print("From [artichoke/asparagus/broccoli/brussels sprouts/cabbage/carrot/cauliflower/celery/chicory/chinese cabbage/egg plant/fructose/garlic/ginger/glucose/green soybean/horseradish/kale/kidney bean/lactose/lettuce/mustard spinach/okra/onion/parsley/peas/potato/radish root/shallot/shiitake  mushroom/spinach/sugar/sugar beet/sugarcane/sweet pepper/sweet potato/tomato/turnip root/yam] enter in how many u have allergy")
            aqua = int(input())
            for i in range(aqua):
                vegetable = input("artichoke/asparagus/broccoli/brussels sprouts/cabbage/carrot/cauliflower/celery/chicory/chinese cabbage/egg plant/fructose/garlic/ginger/glucose/green soybean/horseradish/kale/kidney bean/lactose/lettuce/mustard spinach/okra/onion/parsley/peas/potato/radish root/shallot/shiitake  mushroom/spinach/sugar/sugar beet/sugarcane/sweet pepper/sweet potato/tomato/turnip root/yam")
                both_list.append(vegetable)
        elif user_input[i] == 'cereal grain and pulse':
            print("From [barley/bean/black-eyed bean/broad bean/buckwheat/butter bean/corn/lentil/lima bean/peanut/peas/popcorn/rice/rye/soybean/sultani/sweet corn/wheat/white bean] enter in how many u have allergy")
            aqua = int(input())
            for i in range(aqua):
                cereal = input("barley/bean/black-eyed bean/broad bean/buckwheat/butter bean/corn/lentil/lima bean/peanut/peas/popcorn/rice/rye/soybean/sultani/sweet corn/wheat/white bean")
                both_list.append(cereal)
        elif user_input[i] == 'spice and herb':
            print("From [peppermint/sansho/spearmint] enter in how many u have allergy")
            aqua = int(input())
            for i in range(aqua):
                spice = input("peppermint/sansho/spearmint")
                both_list.append(spice)
        elif user_input[i] == 'tea':
            tea = input("tea")
            both_list.append(tea)
# Out:
# class of allergy [plant/animal/both]:plant
# from [nut and seed/fruit/vegetable/cereal grain and pulse/spice and herb/tea] enter in how may u have allergy
# 2
# [nut and seed/fruit/vegetable/cereal grain and pulse/spice and herb/tea]vegetable
# [nut and seed/fruit/vegetable/cereal grain and pulse/spice and herb/tea]nut and seed
# From [artichoke/asparagus/broccoli/brussels sprouts/cabbage/carrot/cauliflower/celery/chicory/chinese cabbage/egg plant/fructose/garlic/ginger/glucose/green soybean/horseradish/kale/kidney bean/lactose/lettuce/mustard spinach/okra/onion/parsley/peas/potato/radish root/shallot/shiitake  mushroom/spinach/sugar/sugar beet/sugarcane/sweet pepper/sweet potato/tomato/turnip root/yam] enter in how many u have allergy
# 2
# artichoke/asparagus/broccoli/brussels sprouts/cabbage/carrot/cauliflower/celery/chicory/chinese cabbage/egg plant/fructose/garlic/ginger/glucose/green soybean/horseradish/kale/kidney bean/lactose/lettuce/mustard spinach/okra/onion/parsley/peas/potato/radish root/shallot/shiitake  mushroom/spinach/sugar/sugar beet/sugarcane/sweet pepper/sweet potato/tomato/turnip root/yamcarrot
# artichoke/asparagus/broccoli/brussels sprouts/cabbage/carrot/cauliflower/celery/chicory/chinese cabbage/egg plant/fructose/garlic/ginger/glucose/green soybean/horseradish/kale/kidney bean/lactose/lettuce/mustard spinach/okra/onion/parsley/peas/potato/radish root/shallot/shiitake  mushroom/spinach/sugar/sugar beet/sugarcane/sweet pepper/sweet potato/tomato/turnip root/yamspinach
# From [almond/chestnut/coffee bean/sesame seed/walnut] enter in how many u have allergy
# 2
# almond/chestnut/coffee bean/sesame seed/walnutalmond
# almond/chestnut/coffee bean/sesame seed/walnutwalnut

# %%
print(animal_list)
print(plant_list)
Class
# Out:
# []
# ['carrot', 'spinach', 'almond', 'walnut']
# 'plant'

# %%
both_list
# Out:
# []

# %%
def index_of_food(food_list):
    remove_food = []
    for i in df.unique_ingredients.index:
        for j in df.unique_ingredients[i]:
            if j in food_list:
                remove_food.append(i)
    return remove_food            

if Class == 'plant':
    remove = index_of_food(plant_list)
elif Class == 'animal':
    remove = index_of_food(animal_list)
elif Class == 'both':
    remove = index_of_food(both_list)

# %%
'''for i in remove_food:
    val = df.loc[i]
    afterallergy_data['ingredients']= pd.Series(val.ingredients)
    afterallergy_data['title'] = pd.Series(val.title)
    afterallergy_data['instructions'] = pd.Series(val.instructions)
    afterallergy_data['calories'] = val.calories
    afterallergy_data['fatContent'] = val.fatContent                                         
    afterallergy_data['saturatedFatContent'] = val.saturatedFatContent                                              
    afterallergy_data['cholesterolContent'] = val.cholesterolContent                                      
    afterallergy_data['sodiumContent'] = val.sodiumContent                                                  
    afterallergy_data['carbohydrateContent'] = val.carbohydrateContent                                        
    afterallergy_data['fiberContent'] = val.fiberContent                                                        
    afterallergy_data['sugarContent'] = val.sugarContent                                                    
    afterallergy_data['proteinContent'] = val.proteinContent
    
    
    #new_row = {'ingredients': ing, 'title':title, 'instructions':instruc, 'calories': cal, 'fatContent': fat, 'saturatedFatContent': satFat, 'cholesterolContent': cholesterol, 'sodiumContent':sodium, 'carbohydrateContent': carbo, 'fiberContent':fiber, 'sugarContent':sugar, 'proteinContent':protein}
    #afterallergy_data.append(new_row, ignore_index=True)
    '''

# %%
desired_indices = [i for i in range(len(df.index)) if i not in remove]
desired_df = df.loc[desired_indices]
# Out:
# <ipython-input-576-bf5cf146f430>:2: FutureWarning:
# Passing list-likes to .loc or [] with any missing label will raise
# KeyError in the future, you can use .reindex() as an alternative.
#
# See the documentation here:
# https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#deprecate-loc-reindex-listlike
#   desired_df = df.loc[desired_indices]

# %%
desired_df.head(10)
# Out:
#                                           ingredients  \
# 0   red bell pepper seeded diced yellow bell peppe...
# 2   ounce low-fat vanilla yogurt medium strawberry...
# 3                                                 NaN
# 4                                                 NaN
# 5   ounce uncooked linguine tablespoon fresh lemon...
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9   poblano pepper roasted seed removed sliced hal...
# 10                                                NaN
#
#                                                   url  \
# 0   http://www.food.com/recipe/tropical-fruit-sals...
# 2   http://www.food.com/recipe/triple-fruit-yogurt...
# 3                                                 NaN
# 4                                                 NaN
# 5   http://www.food.com/recipe/lemon-tossed-lingui...
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9   http://www.food.com/recipe/quinoa-stuffed-pobl...
# 10                                                NaN
#
#                                                 title          id  \
# 0   Tropical Fruit Salsa With Jalapeno and Bell Pe...  1a164f0112
# 2                           Triple Fruit Yogurt Shake  026da70afa
# 3                                                 NaN         NaN
# 4                                                 NaN         NaN
# 5                               Lemon Tossed Linguine  016244257a
# 6                                                 NaN         NaN
# 7                                                 NaN         NaN
# 8                                                 NaN         NaN
# 9                             Quinoa Stuffed Poblanos  1b8bfbd51b
# 10                                                NaN         NaN
#
#                                          instructions  \
# 0   [{'text': 'Combine all ingredients in a large ...
# 2   [{'text': 'In blender combine yogurt, strawber...
# 3                                                 NaN
# 4                                                 NaN
# 5   [{'text': 'Cook linguine according to package,...
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9   [{'text': 'Preheat oven to 350 degrees.'}, {'t...
# 10                                                NaN
#
#                                             nutrition  calories  fatContent  \
# 0   {'calories': '133.3', 'fatContent': '0.7', 'sa...     133.3         0.7
# 2   {'calories': '170.2', 'fatContent': '1.3', 'sa...     170.2         1.3
# 3                                                 NaN       NaN         NaN
# 4                                                 NaN       NaN         NaN
# 5   {'calories': '328.6', 'fatContent': '3.4', 'sa...     328.6         3.4
# 6                                                 NaN       NaN         NaN
# 7                                                 NaN       NaN         NaN
# 8                                                 NaN       NaN         NaN
# 9   {'calories': '163.8', 'fatContent': '8.8', 'sa...     163.8         8.8
# 10                                                NaN       NaN         NaN
#
#     saturatedFatContent  cholesterolContent  sodiumContent  \
# 0                   0.1                 0.0           12.7
# 2                   0.5                 2.5           36.5
# 3                   NaN                 NaN            NaN
# 4                   NaN                 NaN            NaN
# 5                   1.3                 6.1          110.2
# 6                   NaN                 NaN            NaN
# 7                   NaN                 NaN            NaN
# 8                   NaN                 NaN            NaN
# 9                   3.9                18.6          178.6
# 10                  NaN                 NaN            NaN
#
#     carbohydrateContent  fiberContent  sugarContent  proteinContent  \
# 0                  32.6           5.2          18.0             2.8
# 2                  39.0           4.6          27.8             4.2
# 3                   NaN           NaN           NaN             NaN
# 4                   NaN           NaN           NaN             NaN
# 5                  60.8           2.8           2.5            12.9
# 6                   NaN           NaN           NaN             NaN
# 7                   NaN           NaN           NaN             NaN
# 8                   NaN           NaN           NaN             NaN
# 9                  16.1           3.5           2.3             7.3
# 10                  NaN           NaN           NaN             NaN
#
#                                    unique_ingredients
# 0   [diced, onion, stevia, cilantro, g, seeded, be...
# 2   [low-fat, stemmed, kiwi, strawberry, teaspoon,...
# 3                                                 NaN
# 4                                                 NaN
# 5   [dried, reduced, parmesan, lemon, peel, cornst...
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9   [diced, dried, cilantro, shallot, corn, oil, o...
# 10                                                NaN

# %%
desired_df = desired_df.dropna()

# %%
desired_df.head(10)
# Out:
#                                           ingredients  \
# 0   red bell pepper seeded diced yellow bell peppe...
# 2   ounce low-fat vanilla yogurt medium strawberry...
# 5   ounce uncooked linguine tablespoon fresh lemon...
# 9   poblano pepper roasted seed removed sliced hal...
# 11  g strong flour tablespoon dried yeast teaspoon...
# 12  cup vegan margarine cup brown sugar packed cup...
# 13  large tomato plum tomato tablespoon butter mel...
# 15  ounce cream cheese softened ounce marshmallow ...
# 16  tablespoon butter cup brown sugar packed plum ...
# 18  ounce lime juice ounce sugar syrup ounce pinea...
#
#                                                   url  \
# 0   http://www.food.com/recipe/tropical-fruit-sals...
# 2   http://www.food.com/recipe/triple-fruit-yogurt...
# 5   http://www.food.com/recipe/lemon-tossed-lingui...
# 9   http://www.food.com/recipe/quinoa-stuffed-pobl...
# 11  http://www.food.com/recipe/tonis-pizza-dough-3...
# 12  http://www.food.com/recipe/caramel-buttercream...
# 13  http://www.food.com/recipe/grilled-stuffed-moz...
# 15  http://www.food.com/recipe/orange-marshmallow-...
# 16  http://www.food.com/recipe/plum-delicious-upsi...
# 18  http://www.food.com/recipe/jamaican-delight-87701
#
#                                                 title          id  \
# 0   Tropical Fruit Salsa With Jalapeno and Bell Pe...  1a164f0112
# 2                           Triple Fruit Yogurt Shake  026da70afa
# 5                               Lemon Tossed Linguine  016244257a
# 9                             Quinoa Stuffed Poblanos  1b8bfbd51b
# 11                                 Toni's Pizza Dough  026d16ad66
# 12  Caramel Buttercream Frosting (For Everyone, In...  19156ab911
# 13                Grilled Stuffed Mozzarella Tomatoes  1acf0be97a
# 15                       Orange Marshmallow Fruit Dip  01e8a5eafa
# 16                    Plum Delicious Upside-Down Cake  192ae3d618
# 18                                   Jamaican Delight  1ae294b081
#
#                                          instructions  \
# 0   [{'text': 'Combine all ingredients in a large ...
# 2   [{'text': 'In blender combine yogurt, strawber...
# 5   [{'text': 'Cook linguine according to package,...
# 9   [{'text': 'Preheat oven to 350 degrees.'}, {'t...
# 11  [{'text': 'Mix the flour, salt and pepper.'}, ...
# 12  [{'text': 'Stir the margarine and brown sugar ...
# 13  [{'text': 'Halve tomatoes and scoop out inside...
# 15  [{'text': 'Blend all ingredients until smooth....
# 16  [{'text': 'Preheat oven to 350 degrees Fahrenh...
# 18  [{'text': 'Combine ingredients in Blender add ...
#
#                                             nutrition  calories  fatContent  \
# 0   {'calories': '133.3', 'fatContent': '0.7', 'sa...     133.3         0.7
# 2   {'calories': '170.2', 'fatContent': '1.3', 'sa...     170.2         1.3
# 5   {'calories': '328.6', 'fatContent': '3.4', 'sa...     328.6         3.4
# 9   {'calories': '163.8', 'fatContent': '8.8', 'sa...     163.8         8.8
# 11  {'calories': '386.8', 'fatContent': '5.5', 'sa...     386.8         5.5
# 12  {'calories': '171.3', 'fatContent': '4.3', 'sa...     171.3         4.3
# 13  {'calories': '119.5', 'fatContent': '8', 'satu...     119.5         8.0
# 15  {'calories': '123.5', 'fatContent': '6.7', 'sa...     123.5         6.7
# 16  {'calories': '173.2', 'fatContent': '3.3', 'sa...     173.2         3.3
# 18  {'calories': '130.2', 'fatContent': '0.1', 'sa...     130.2         0.1
#
#     saturatedFatContent  cholesterolContent  sodiumContent  \
# 0                   0.1                 0.0           12.7
# 2                   0.5                 2.5           36.5
# 5                   1.3                 6.1          110.2
# 9                   3.9                18.6          178.6
# 11                  0.8                 0.0          391.5
# 12                  1.1                 0.0            5.2
# 13                  4.7                26.2          203.1
# 15                  4.2                20.8           70.0
# 16                  1.7                41.4          171.0
# 18                  0.0                 0.0            1.8
#
#     carbohydrateContent  fiberContent  sugarContent  proteinContent  \
# 0                  32.6           5.2          18.0             2.8
# 2                  39.0           4.6          27.8             4.2
# 5                  60.8           2.8           2.5            12.9
# 9                  16.1           3.5           2.3             7.3
# 11                 72.7           2.9           2.1            10.3
# 12                 34.0           0.0          33.3             0.1
# 13                  5.2           1.4           2.8             7.4
# 15                 14.6           0.1           8.3             1.6
# 16                 31.6           1.3          14.4             4.4
# 18                  8.6           0.2           5.9             0.3
#
#                                    unique_ingredients
# 0   [diced, onion, stevia, cilantro, g, seeded, be...
# 2   [low-fat, stemmed, kiwi, strawberry, teaspoon,...
# 5   [dried, reduced, parmesan, lemon, peel, cornst...
# 9   [diced, dried, cilantro, shallot, corn, oil, o...
# 11  [fresh, lukewarm, ground, -, dried, salt, teas...
# 12  [packed, sugar, margarine, brown, teaspoon, co...
# 13  [breadcrumb, basil, cubed, plum, teaspoon, lar...
# 15  [freshly, dash, rind, creme, softened, marshma...
# 16  [getting, low-fat, substitute, baking, lemon, ...
# 18  [sugar, rum, lime, triple, syrup, appleton, se...

# %%
desired_df.unique_ingredients
# Out:
# 0      [diced, onion, stevia, cilantro, g, seeded, be...
# 2      [low-fat, stemmed, kiwi, strawberry, teaspoon,...
# 5      [dried, reduced, parmesan, lemon, peel, cornst...
# 9      [diced, dried, cilantro, shallot, corn, oil, o...
# 11     [fresh, lukewarm, ground, -, dried, salt, teas...
#                              ...
# 631    [raisin, baking, bran, sugar, oat, teaspoon, p...
# 633    [slice, orange, -inch, thick, sherbet, juice, ...
# 635    [allspice, baking, ginger, granulated, nutmeg,...
# 636    [diced, tart, used, -, prepared, chicken, lb, ...
# 637    [diced, onion, vinegar, oil, garlic, velveeta,...
# Name: unique_ingredients, Length: 467, dtype: object

# %%
print("total no of recommendations: {}".format(desired_df.shape[0]))
# Out:
# total no of recommendations: 467

# %%
desired_df.unique_ingredients[2]
# Out:
# ['low-fat',
#  'stemmed',
#  'kiwi',
#  'strawberry',
#  'teaspoon',
#  'chopped',
#  'honey',
#  'fresh',
#  'leaf',
#  'medium',
#  'vanilla',
#  'small',
#  'sprig',
#  'tablespoon',
#  'peeled',
#  'yogurt',
#  'mint',
#  'optional',
#  'banana',
#  'ounce']

# %% [markdown]
# # acc to khushali mams idea

# %%
lst = []
print("enter in how many foods you have allergy?")
num = int(input())
for i in range(num):
    n = input("enter the food names u have allergy to:")
    lst.append(n)
# Out:
# enter in how many foods you have allergy?
# 3
# enter the food names u have allergy to:strawberry
# enter the food names u have allergy to:coconut
# enter the food names u have allergy to:milk

# %%
lst
# Out:
# ['strawberry', 'coconut', 'milk']

# %%
def index_of_food(food_list):
    remove_food = []
    for i in df.unique_ingredients.index:
        for j in df.unique_ingredients[i]:
            if j in food_list:
                remove_food.append(i)
    return remove_food  

junk = index_of_food(lst)

# %%
desired_indices = [i for i in range(len(df.index)) if i not in junk]
desired_df = df.loc[desired_indices]
# Out:
# <ipython-input-586-da06c6be2423>:2: FutureWarning:
# Passing list-likes to .loc or [] with any missing label will raise
# KeyError in the future, you can use .reindex() as an alternative.
#
# See the documentation here:
# https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#deprecate-loc-reindex-listlike
#   desired_df = df.loc[desired_indices]

# %%
desired_df = desired_df.dropna()

# %%
desired_df.head(10)
# Out:
#                                           ingredients  \
# 0   red bell pepper seeded diced yellow bell peppe...
# 1   tablespoon light butter smart balance land ola...
# 9   poblano pepper roasted seed removed sliced hal...
# 11  g strong flour tablespoon dried yeast teaspoon...
# 12  cup vegan margarine cup brown sugar packed cup...
# 13  large tomato plum tomato tablespoon butter mel...
# 15  ounce cream cheese softened ounce marshmallow ...
# 16  tablespoon butter cup brown sugar packed plum ...
# 18  ounce lime juice ounce sugar syrup ounce pinea...
# 19  cup salt-free seasoned dried breadcrumb c s be...
#
#                                                   url  \
# 0   http://www.food.com/recipe/tropical-fruit-sals...
# 1   http://www.food.com/recipe/the-best-lower-fat-...
# 9   http://www.food.com/recipe/quinoa-stuffed-pobl...
# 11  http://www.food.com/recipe/tonis-pizza-dough-3...
# 12  http://www.food.com/recipe/caramel-buttercream...
# 13  http://www.food.com/recipe/grilled-stuffed-moz...
# 15  http://www.food.com/recipe/orange-marshmallow-...
# 16  http://www.food.com/recipe/plum-delicious-upsi...
# 18  http://www.food.com/recipe/jamaican-delight-87701
# 19  http://www.food.com/recipe/alyssas-favorite-fi...
#
#                                                 title          id  \
# 0   Tropical Fruit Salsa With Jalapeno and Bell Pe...  1a164f0112
# 1           The Best Lower Fat Chocolate Chip Cookies  1a801c28c2
# 9                             Quinoa Stuffed Poblanos  1b8bfbd51b
# 11                                 Toni's Pizza Dough  026d16ad66
# 12  Caramel Buttercream Frosting (For Everyone, In...  19156ab911
# 13                Grilled Stuffed Mozzarella Tomatoes  1acf0be97a
# 15                       Orange Marshmallow Fruit Dip  01e8a5eafa
# 16                    Plum Delicious Upside-Down Cake  192ae3d618
# 18                                   Jamaican Delight  1ae294b081
# 19                             Alyssa's Favorite Fish  198c85c851
#
#                                          instructions  \
# 0   [{'text': 'Combine all ingredients in a large ...
# 1   [{'text': 'Preheat oven to 350 degrees Fahrenh...
# 9   [{'text': 'Preheat oven to 350 degrees.'}, {'t...
# 11  [{'text': 'Mix the flour, salt and pepper.'}, ...
# 12  [{'text': 'Stir the margarine and brown sugar ...
# 13  [{'text': 'Halve tomatoes and scoop out inside...
# 15  [{'text': 'Blend all ingredients until smooth....
# 16  [{'text': 'Preheat oven to 350 degrees Fahrenh...
# 18  [{'text': 'Combine ingredients in Blender add ...
# 19  [{'text': 'Preheat oven to 350 degrees.'}, {'t...
#
#                                             nutrition  calories  fatContent  \
# 0   {'calories': '133.3', 'fatContent': '0.7', 'sa...     133.3         0.7
# 1   {'calories': '115.2', 'fatContent': '6.2', 'sa...     115.2         6.2
# 9   {'calories': '163.8', 'fatContent': '8.8', 'sa...     163.8         8.8
# 11  {'calories': '386.8', 'fatContent': '5.5', 'sa...     386.8         5.5
# 12  {'calories': '171.3', 'fatContent': '4.3', 'sa...     171.3         4.3
# 13  {'calories': '119.5', 'fatContent': '8', 'satu...     119.5         8.0
# 15  {'calories': '123.5', 'fatContent': '6.7', 'sa...     123.5         6.7
# 16  {'calories': '173.2', 'fatContent': '3.3', 'sa...     173.2         3.3
# 18  {'calories': '130.2', 'fatContent': '0.1', 'sa...     130.2         0.1
# 19  {'calories': '206.4', 'fatContent': '23', 'sat...     206.4        23.0
#
#     saturatedFatContent  cholesterolContent  sodiumContent  \
# 0                   0.1                 0.0           12.7
# 1                   3.7                12.7           87.3
# 9                   3.9                18.6          178.6
# 11                  0.8                 0.0          391.5
# 12                  1.1                 0.0            5.2
# 13                  4.7                26.2          203.1
# 15                  4.2                20.8           70.0
# 16                  1.7                41.4          171.0
# 18                  0.0                 0.0            1.8
# 19                 14.6                61.0          163.6
#
#     carbohydrateContent  fiberContent  sugarContent  proteinContent  \
# 0                  32.6           5.2          18.0             2.8
# 1                  14.6           0.7           9.2             1.6
# 9                  16.1           3.5           2.3             7.3
# 11                 72.7           2.9           2.1            10.3
# 12                 34.0           0.0          33.3             0.1
# 13                  5.2           1.4           2.8             7.4
# 15                 14.6           0.1           8.3             1.6
# 16                 31.6           1.3          14.4             4.4
# 18                  8.6           0.2           5.9             0.3
# 19                  1.0           0.1           0.3             0.3
#
#                                    unique_ingredients
# 0   [diced, onion, stevia, cilantro, g, seeded, be...
# 1   [consistency, baking, walnut, balance, oatmeal...
# 9   [diced, dried, cilantro, shallot, corn, oil, o...
# 11  [fresh, lukewarm, ground, -, dried, salt, teas...
# 12  [packed, sugar, margarine, brown, teaspoon, co...
# 13  [breadcrumb, basil, cubed, plum, teaspoon, lar...
# 15  [freshly, dash, rind, creme, softened, marshma...
# 16  [getting, low-fat, substitute, baking, lemon, ...
# 18  [sugar, rum, lime, triple, syrup, appleton, se...
# 19  [choice, dried, pam, fillet, lemon, breadcrumb...

# %%
print("total no of recommendations: {}".format(desired_df.shape[0]))
# Out:
# total no of recommendations: 458

# %%
desired_df.unique_ingredients
# Out:
# 0      [diced, onion, stevia, cilantro, g, seeded, be...
# 1      [consistency, baking, walnut, balance, oatmeal...
# 9      [diced, dried, cilantro, shallot, corn, oil, o...
# 11     [fresh, lukewarm, ground, -, dried, salt, teas...
# 12     [packed, sugar, margarine, brown, teaspoon, co...
#                              ...
# 629    [allspice, dried, roast, shallot, standing, co...
# 630    [kiwi, melon, seeded, midori, cubed, thinly, s...
# 633    [slice, orange, -inch, thick, sherbet, juice, ...
# 636    [diced, tart, used, -, prepared, chicken, lb, ...
# 637    [diced, onion, vinegar, oil, garlic, velveeta,...
# Name: unique_ingredients, Length: 458, dtype: object

# %%
desired_df.unique_ingredients[0]
# Out:
# ['diced',
#  'onion',
#  'stevia',
#  'cilantro',
#  'g',
#  'seeded',
#  'bell',
#  'lime',
#  '-inch',
#  'minced',
#  'red',
#  'yellow',
#  'fresh',
#  'medium',
#  'tablespoon',
#  'pepper',
#  'papaya',
#  'jalapeno',
#  'peeled',
#  'pineapple',
#  'juice',
#  'cup',
#  'piece']

# %%
lst
# Out:
# ['strawberry', 'coconut', 'milk']
